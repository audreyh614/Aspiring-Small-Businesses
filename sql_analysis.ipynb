# %% [markdown]
# # Installing Packages

# %%
# !pip install ipython-sql

# !pip install mysqlclient

# !pip install pymysql
# Out:
# Requirement already satisfied: ipython-sql in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: six in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython>=1.0 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.19.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.3.20)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlparse in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: prettytable<1 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (50.3.1.post20201107)
# Requirement already satisfied: pygments in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.7.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.8)
# Requirement already satisfied: backcall in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: decorator in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: pickleshare in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.17.1)
# Requirement already satisfied: wcwidth in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: mysqlclient in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: pymysql in /Users/audrey/opt/anaconda3/lib/python3.8/site-packages (1.0.2)

# %%
# %reload_ext sql

# %%
# %sql mysql://admin:sql_2021@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants

# %% [markdown]
# # Primary Question
#
# ### _What are the top three businesses that applied for the highest grant amount for each industry? (with 1 being the highest)_
#
# Return the top 3 companies for each respective industry, how much they are requesting, and their rank.
#
#
# SQL Features Used: _CTE, RANK, ORDER BY, GROUP BY, ROUND, AVG_

# %%
# %%sql
# WITH GrantApps_cte AS (
#     SELECT
#         company_name AS company,
#         industry,
#         amount_requested,
#     RANK() OVER (
#         PARTITION BY industry
#         ORDER BY SUM(amount_requested) DESC
#     ) AS industry_rank
#     FROM StateWideGrantApplication
#     GROUP BY company_name
# )
# SELECT *
# FROM GrantApps_cte
# WHERE industry_rank <= 3
# GROUP BY company;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 24 rows affected.
# [('Ac Mattis Ornare Corporation', 'Advertising', 149489, 1),
#  ('Et Netus PC', 'Advertising', 146067, 2),
#  ('Sem PC', 'Advertising', 144693, 3),
#  ('Pede Institute', 'Food Services', 148985, 1),
#  ('Nullam Lobortis Quam Incorporated', 'Food Services', 147295, 2),
#  ('Rutrum Corporation', 'Food Services', 141116, 3),
#  ('Sed Limited', 'Health, Beauty, and Fitness', 146148, 1),
#  ('Malesuada Institute', 'Health, Beauty, and Fitness', 29195, 2),
#  ('Magna Consulting', 'Health, Beauty, and Fitness', 25507, 3),
#  ('Cras Corp.', 'Maintenance', 123564, 1),
#  ('Consequat Purus Institute', 'Maintenance', 148169, 2),
#  ('Tincidunt PC', 'Maintenance', 142208, 3),
#  ('Nunc Lectus Limited', 'Repair Services', 150000, 1),
#  ('Nunc Corp.', 'Repair Services', 149089, 2),
#  ('Eu Tempor Associates', 'Repair Services', 148155, 3),
#  ('Orci Foundation', 'Retail', 146301, 1),
#  ('Ut Tincidunt Orci Foundation', 'Retail', 141659, 2),
#  ('Hendrerit Id Ante Company', 'Retail', 139878, 3),
#  ('Malesuada Vel Corp.', 'Sports and Recreation', 147104, 1),
#  ('Sed Est Nunc Limited', 'Sports and Recreation', 145695, 2),
#  ('Amet Company', 'Sports and Recreation', 143113, 3),
#  ('Primis In Company', 'Technology', 147172, 1),
#  ('Lacus Nulla Tincidunt Corporation', 'Technology', 145175, 2),
#  ('Ante LLC', 'Technology', 143898, 3)]

# %% [markdown]
# # Sub-Question 1
#
# __Business Request:__ _The team would like to gage what industry thus far is their biggest audience as represented in the current applications._
#
# __Question:__ _How many businesses applied for a grant per industry? What industry did we receive the most applications from? Compare the applications amongst each other. Provide the list of industries, the total amount overall requested by businesses within a given industry, the average grant amount requested per industry, and the average grant amount requested amongst all (individual) applications._
#
# Follow Up Request: Identify each business by the amount they requested to designate them within a given grant range classification.
#
# __Business Justification:__ _Analysts want to see a snapshot of what the current status is of applications, framing it in this way allows for them to see the bigger picture._
#
# SQL Features Used: _CTE, COUNT, SUM, ROUND, AVG, GROUP BY, SUBQUERY, CASE_

# %%
# %%sql
# WITH GrantApps_cte2 AS (
#     SELECT
#         COUNT(company_name) AS number_of_businesses,
#         industry,
#         SUM(amount_requested) AS total_requested_per_industry,
#         ROUND(AVG(amount_requested)) AS average_requested_per_industry
#     FROM StateWideGrantApplication
#     GROUP BY industry
# )
# SELECT *,
#     (
#         SELECT
#             ROUND(AVG(amount_requested)) AS average_requested
#         FROM StateWideGrantApplication
#     ) AS average_amount_requested_total
# FROM GrantApps_cte2
# GROUP BY industry;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 8 rows affected.
# [(71, 'Food Services', Decimal('4995064'), Decimal('70353'), Decimal('79059')),
#  (43, 'Retail', Decimal('3102570'), Decimal('72153'), Decimal('79059')),
#  (45, 'Advertising', Decimal('3529301'), Decimal('78429'), Decimal('79059')),
#  (51, 'Sports and Recreation', Decimal('4008968'), Decimal('78607'), Decimal('79059')),
#  (61, 'Technology', Decimal('5150998'), Decimal('84443'), Decimal('79059')),
#  (51, 'Maintenance', Decimal('4255147'), Decimal('83434'), Decimal('79059')),
#  (43, 'Repair Services', Decimal('3554735'), Decimal('82668'), Decimal('79059')),
#  (35, 'Health, Beauty, and Fitness', Decimal('3026873'), Decimal('86482'), Decimal('79059'))]

# %%
# %%sql
# SELECT
#     company_name,
#     industry,
#     amount_requested,
#     CASE
#         WHEN amount_requested BETWEEN 1000 AND 10000 THEN 'tiny'
#         WHEN amount_requested BETWEEN 10000 AND 30000 THEN 'small'
#         WHEN amount_requested BETWEEN 30000 AND 70000 THEN 'moderate'
#         WHEN amount_requested BETWEEN 70000 AND 80000 THEN 'average'
#         WHEN amount_requested BETWEEN 80000 AND 110000 THEN 'large'
#         WHEN amount_requested BETWEEN 110000 AND 150000 THEN 'huge'
#     END AS grant_range
# FROM StateWideGrantApplication
# GROUP BY company_name;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 395 rows affected.
# [('Malesuada Fringilla Est Inc.', 'Food Services', 67939, 'moderate'),
#  ('Risus Odio Institute', 'Retail', 19281, 'small'),
#  ('Nisi Dictum Consulting', 'Advertising', 77687, 'average'),
#  ('Mauris Consulting', 'Retail', 7681, 'tiny'),
#  ('Sagittis Nullam Industries', 'Sports and Recreation', 27749, 'small'),
#  ('Leo In Lobortis Consulting', 'Technology', 132278, 'huge'),
#  ('Tortor At Risus LLC', 'Maintenance', 79642, 'average'),
#  ('Sit Amet Massa Corp.', 'Advertising', 72814, 'average'),
#  ('Iaculis Odio Nam Corporation', 'Food Services', 140576, 'huge'),
#  ('Diam Ltd', 'Food Services', 38441, 'moderate'),
#  ('Eget Magna Suspendisse Consulting', 'Sports and Recreation', 52911, 'moderate'),
#  ('Quisque Fringilla Euismod PC', 'Sports and Recreation', 128211, 'huge'),
#  ('Ultrices A Auctor PC', 'Advertising', 127657, 'huge'),
#  ('Non Justo Corporation', 'Retail', 125185, 'huge'),
#  ('Adipiscing Elit Etiam Industries', 'Maintenance', 119060, 'huge'),
#  ('Ipsum Primis LLP', 'Advertising', 29134, 'small'),
#  ('Est Mollis Non Limited', 'Maintenance', 139266, 'huge'),
#  ('Nonummy Limited', 'Retail', 138300, 'huge'),
#  ('Cras Corp.', 'Maintenance', 123564, 'huge'),
#  ('Pede Foundation', 'Repair Services', 113991, 'huge'),
#  ('Malesuada Company', 'Technology', 68435, 'moderate'),
#  ('Orci Corporation', 'Repair Services', 77767, 'average'),
#  ('Malesuada Consulting', 'Retail', 137615, 'huge'),
#  ('Vitae Risus Company', 'Health, Beauty, and Fitness', 127751, 'huge'),
#  ('Pellentesque A Foundation', 'Maintenance', 102621, 'large'),
#  ('Tristique Senectus Et Company', 'Maintenance', 4291, 'tiny'),
#  ('Aenean Inc.', 'Advertising', 22710, 'small'),
#  ('Sed Turpis Nec Company', 'Food Services', 19494, 'small'),
#  ('Aliquam Corp.', 'Food Services', 57992, 'moderate'),
#  ('Erat Corporation', 'Sports and Recreation', 90452, 'large'),
#  ('Ac Corporation', 'Health, Beauty, and Fitness', 137403, 'huge'),
#  ('A Industries', 'Sports and Recreation', 27568, 'small'),
#  ('Est Company', 'Advertising', 20001, 'small'),
#  ('Cras Limited', 'Sports and Recreation', 24587, 'small'),
#  ('Dolor Corp.', 'Repair Services', 101065, 'large'),
#  ('Urna Justo Industries', 'Repair Services', 108792, 'large'),
#  ('Eu Nibh Vulputate Inc.', 'Health, Beauty, and Fitness', 127981, 'huge'),
#  ('Duis PC', 'Food Services', 13832, 'small'),
#  ('Facilisis Lorem Tristique Incorporated', 'Sports and Recreation', 94249, 'large'),
#  ('Erat Volutpat Nulla PC', 'Retail', 7836, 'tiny'),
#  ('Eros Nec Tellus Company', 'Maintenance', 117625, 'huge'),
#  ('Felis Adipiscing Fringilla Associates', 'Food Services', 139742, 'huge'),
#  ('Pellentesque Massa Lobortis Corporation', 'Technology', 143289, 'huge'),
#  ('Augue Ltd', 'Retail', 88295, 'large'),
#  ('Id Enim LLP', 'Repair Services', 96877, 'large'),
#  ('Amet Institute', 'Technology', 31379, 'moderate'),
#  ('Dolor Ltd', 'Advertising', 10197, 'small'),
#  ('Tincidunt Tempus Risus Corp.', 'Maintenance', 123202, 'huge'),
#  ('Quam Dignissim Pharetra Company', 'Advertising', 94636, 'large'),
#  ('Id Enim Curabitur Incorporated', 'Maintenance', 120628, 'huge'),
#  ('Dignissim Lacus Aliquam LLC', 'Retail', 39593, 'moderate'),
#  ('Lacinia PC', 'Repair Services', 91648, 'large'),
#  ('Ante Nunc Mauris Corp.', 'Advertising', 126898, 'huge'),
#  ('Venenatis Vel Associates', 'Technology', 76709, 'average'),
#  ('Ac Mattis Ornare Corporation', 'Advertising', 149489, 'huge'),
#  ('Nec Eleifend Non Industries', 'Food Services', 134376, 'huge'),
#  ('Proin Non Massa Associates', 'Sports and Recreation', 88525, 'large'),
#  ('Sapien Limited', 'Technology', 125394, 'huge'),
#  ('Sapien Cursus In Inc.', 'Advertising', 63925, 'moderate'),
#  ('Rhoncus Id Mollis Corporation', 'Health, Beauty, and Fitness', 106116, 'large'),
#  ('Ac Company', 'Maintenance', 110979, 'huge'),
#  ('Ultricies Company', 'Retail', 35394, 'moderate'),
#  ('Nisl Company', 'Health, Beauty, and Fitness', 91955, 'large'),
#  ('Risus Donec Limited', 'Repair Services', 43027, 'moderate'),
#  ('Aliquet Limited', 'Maintenance', 22931, 'small'),
#  ('Eget Ipsum Company', 'Retail', 126295, 'huge'),
#  ('Ac Eleifend Industries', 'Advertising', 30200, 'moderate'),
#  ('Vitae Institute', 'Food Services', 86249, 'large'),
#  ('Odio Sagittis Semper PC', 'Maintenance', 31686, 'moderate'),
#  ('Placerat Cras Foundation', 'Technology', 114973, 'huge'),
#  ('Lectus Nullam Suscipit Inc.', 'Technology', 104780, 'large'),
#  ('Lorem Vitae Consulting', 'Sports and Recreation', 78545, 'average'),
#  ('Euismod Foundation', 'Sports and Recreation', 35501, 'moderate'),
#  ('Dui Limited', 'Technology', 124937, 'huge'),
#  ('Ut Aliquam Iaculis Industries', 'Sports and Recreation', 57080, 'moderate'),
#  ('Aenean Egestas Institute', 'Retail', 133382, 'huge'),
#  ('Eu Metus Institute', 'Advertising', 3959, 'tiny'),
#  ('A Scelerisque Sed Institute', 'Advertising', 75772, 'average'),
#  ('Tincidunt PC', 'Maintenance', 142208, 'huge'),
#  ('Varius Ultrices LLC', 'Sports and Recreation', 122147, 'huge'),
#  ('Libero Associates', 'Health, Beauty, and Fitness', 116031, 'huge'),
#  ('Sapien Molestie Corp.', 'Sports and Recreation', 104346, 'large'),
#  ('Imperdiet Institute', 'Technology', 128950, 'huge'),
#  ('Donec Consectetuer Mauris Foundation', 'Technology', 121654, 'huge'),
#  ('Quis Pede Institute', 'Food Services', 45650, 'moderate'),
#  ('Ipsum Corporation', 'Retail', 125089, 'huge'),
#  ('Est LLP', 'Sports and Recreation', 85557, 'large'),
#  ('Malesuada Vel Corp.', 'Sports and Recreation', 147104, 'huge'),
#  ('Massa Non Incorporated', 'Food Services', 26003, 'small'),
#  ('Malesuada Institute', 'Health, Beauty, and Fitness', 29195, 'small'),
#  ('Quam A Felis PC', 'Food Services', 93463, 'large'),
#  ('Tincidunt Aliquam Arcu LLP', 'Sports and Recreation', 63404, 'moderate'),
#  ('Nunc Lectus Limited', 'Repair Services', 150000, 'huge'),
#  ('Duis LLP', 'Maintenance', 85935, 'large'),
#  ('A Purus Duis Corp.', 'Sports and Recreation', 81020, 'large'),
#  ('Mollis Foundation', 'Retail', 117034, 'huge'),
#  ('Lectus Ltd', 'Food Services', 36752, 'moderate'),
#  ('Eleifend Nec Malesuada Limited', 'Repair Services', 138325, 'huge'),
#  ('Ipsum Nunc LLP', 'Technology', 71317, 'average'),
#  ('Libero Nec Company', 'Technology', 71479, 'average'),
#  ('Nec Cursus LLC', 'Retail', 132805, 'huge'),
#  ('Habitant LLC', 'Sports and Recreation', 91857, 'large'),
#  ('Nec Leo Morbi Ltd', 'Advertising', 20511, 'small'),
#  ('Magna Consulting', 'Health, Beauty, and Fitness', 25507, 'small'),
#  ('Nec LLC', 'Maintenance', 60657, 'moderate'),
#  ('Nullam Nisl Maecenas Incorporated', 'Sports and Recreation', 1614, 'tiny'),
#  ('Augue Sed Molestie Foundation', 'Sports and Recreation', 100705, 'large'),
#  ('Magnis Dis Parturient Associates', 'Maintenance', 42614, 'moderate'),
#  ('Non Massa Non PC', 'Food Services', 35953, 'moderate'),
#  ('Accumsan Laoreet Ipsum Incorporated', 'Health, Beauty, and Fitness', 108096, 'large'),
#  ('Hendrerit Id Ante Company', 'Retail', 139878, 'huge'),
#  ('Et Magna Praesent LLP', 'Food Services', 42481, 'moderate'),
#  ('Arcu Morbi Sit Inc.', 'Sports and Recreation', 143009, 'huge'),
#  ('Risus PC', 'Maintenance', 88929, 'large'),
#  ('Mi Tempor Lorem Corporation', 'Technology', 31977, 'moderate'),
#  ('Lacinia Company', 'Advertising', 71239, 'average'),
#  ('Sit Industries', 'Health, Beauty, and Fitness', 3535, 'tiny'),
#  ('Etiam Foundation', 'Food Services', 82050, 'large'),
#  ('Maecenas Libero Est Company', 'Food Services', 94131, 'large'),
#  ('Aliquam Limited', 'Maintenance', 9515, 'tiny'),
#  ('Risus A Ultricies Consulting', 'Advertising', 117056, 'huge'),
#  ('Cras Associates', 'Retail', 91193, 'large'),
#  ('Lacinia Sed Congue Incorporated', 'Maintenance', 98699, 'large'),
#  ('Augue Incorporated', 'Technology', 77960, 'average'),
#  ('Et Magnis Ltd', 'Food Services', 76107, 'average'),
#  ('Nisl Nulla Limited', 'Food Services', 78411, 'average'),
#  ('Massa Rutrum Institute', 'Sports and Recreation', 114500, 'huge'),
#  ('Donec Felis Orci Consulting', 'Repair Services', 98759, 'large'),
#  ('Aliquam Eros Turpis PC', 'Food Services', 56409, 'moderate'),
#  ('Integer PC', 'Maintenance', 56783, 'moderate'),
#  ('Aliquam Fringilla Cursus Industries', 'Maintenance', 48328, 'moderate'),
#  ('Vulputate Velit Company', 'Technology', 71494, 'average'),
#  ('Lacinia Industries', 'Retail', 133079, 'huge'),
#  ('Suspendisse Dui Fusce PC', 'Health, Beauty, and Fitness', 15748, 'small'),
#  ('Non Sollicitudin A Industries', 'Technology', 77910, 'average'),
#  ('Sollicitudin Foundation', 'Food Services', 74014, 'average'),
#  ('Ullamcorper Duis At Consulting', 'Maintenance', 24232, 'small'),
#  ('Odio Aliquam Vulputate Company', 'Maintenance', 73045, 'average'),
#  ('Nullam Vitae Corp.', 'Technology', 45817, 'moderate'),
#  ('Neque Nullam Ltd', 'Technology', 115125, 'huge'),
#  ('Sodales Ltd', 'Technology', 12886, 'small'),
#  ('Massa Corporation', 'Food Services', 2896, 'tiny'),
#  ('Feugiat Nec Inc.', 'Sports and Recreation', 52987, 'moderate'),
#  ('Rutrum Justo Industries', 'Advertising', 69016, 'moderate'),
#  ('Consectetuer Euismod Incorporated', 'Food Services', 77751, 'average'),
#  ('Nam Company', 'Retail', 3157, 'tiny'),
#  ('Risus LLC', 'Food Services', 106741, 'large'),
#  ('Nascetur Ridiculus Ltd', 'Maintenance', 141171, 'huge'),
#  ('Adipiscing Enim Ltd', 'Advertising', 142885, 'huge'),
#  ('Cursus Vestibulum Foundation', 'Retail', 51724, 'moderate'),
#  ('Sociis Natoque Corp.', 'Health, Beauty, and Fitness', 72843, 'average'),
#  ('Purus Accumsan Interdum Industries', 'Food Services', 48094, 'moderate'),
#  ('Blandit LLP', 'Retail', 97314, 'large'),
#  ('Ut Tincidunt Orci Foundation', 'Retail', 141659, 'huge'),
#  ('Ut Tincidunt Corporation', 'Maintenance', 91104, 'large'),
#  ('Eleifend Cras Sed Industries', 'Sports and Recreation', 107230, 'large'),
#  ('Sed Limited', 'Health, Beauty, and Fitness', 146148, 'huge'),
#  ('Tincidunt Congue Turpis LLC', 'Sports and Recreation', 25014, 'small'),
#  ('Auctor Vitae Aliquet LLC', 'Repair Services', 20379, 'small'),
#  ('Et Corporation', 'Food Services', 123193, 'huge'),
#  ('Fermentum Risus LLP', 'Advertising', 43611, 'moderate'),
#  ('Montes Associates', 'Health, Beauty, and Fitness', 144974, 'huge'),
#  ('Sed Turpis Nec LLC', 'Maintenance', 29733, 'small'),
#  ('Diam Limited', 'Technology', 79325, 'average'),
#  ('Mauris A PC', 'Retail', 16313, 'small'),
#  ('Orci Tincidunt Adipiscing LLP', 'Health, Beauty, and Fitness', 113107, 'huge'),
#  ('Sit Amet Dapibus Company', 'Technology', 27390, 'small'),
#  ('Aenean Institute', 'Food Services', 79092, 'average'),
#  ('Amet Ultricies Company', 'Retail', 37158, 'moderate'),
#  ('Consectetuer PC', 'Food Services', 3192, 'tiny'),
#  ('Amet Diam Inc.', 'Health, Beauty, and Fitness', 16302, 'small'),
#  ('Id Associates', 'Maintenance', 51297, 'moderate'),
#  ('Donec Porttitor Tellus Ltd', 'Technology', 47349, 'moderate'),
#  ('In Sodales PC', 'Advertising', 34018, 'moderate'),
#  ('Neque Et Institute', 'Sports and Recreation', 83600, 'large'),
#  ('Sit Amet Inc.', 'Repair Services', 77282, 'average'),
#  ('Duis Cursus Diam Inc.', 'Health, Beauty, and Fitness', 103407, 'large'),
#  ('At Industries', 'Technology', 50035, 'moderate'),
#  ('Cras Consulting', 'Repair Services', 73465, 'average'),
#  ('Metus In Lorem Foundation', 'Advertising', 3067, 'tiny'),
#  ('Non Incorporated', 'Food Services', 14185, 'small'),
#  ('Mattis Associates', 'Technology', 62693, 'moderate'),
#  ('Mollis Integer Corp.', 'Advertising', 97745, 'large'),
#  ('Lorem Ac Risus LLC', 'Health, Beauty, and Fitness', 105693, 'large'),
#  ('Elit Pretium PC', 'Retail', 33479, 'moderate'),
#  ('Nisi Foundation', 'Technology', 111509, 'huge'),
#  ('Magna Sed Dui Associates', 'Technology', 14966, 'small'),
#  ('Ut Pharetra Limited', 'Technology', 32748, 'moderate'),
#  ('Curae; Donec Ltd', 'Repair Services', 18238, 'small'),
#  ('Eu Corporation', 'Technology', 47276, 'moderate'),
#  ('Enim Mi Associates', 'Retail', 26018, 'small'),
#  ('Ut Dolor Dapibus Incorporated', 'Food Services', 123446, 'huge'),
#  ('Consequat Lectus Foundation', 'Sports and Recreation', 65188, 'moderate'),
#  ('Ipsum Phasellus Vitae Associates', 'Maintenance', 35327, 'moderate'),
#  ('Ligula PC', 'Retail', 29010, 'small'),
#  ('Erat Vitae Industries', 'Technology', 118678, 'huge'),
#  ('Fringilla Euismod Enim PC', 'Maintenance', 29018, 'small'),
#  ('Ut Nulla Incorporated', 'Sports and Recreation', 43120, 'moderate'),
#  ('Massa Mauris LLP', 'Advertising', 49203, 'moderate'),
#  ('Nec Ante LLC', 'Sports and Recreation', 131224, 'huge'),
#  ('Pretium Aliquet LLP', 'Technology', 126174, 'huge'),
#  ('Sed Est Nunc Limited', 'Sports and Recreation', 145695, 'huge'),
#  ('Duis Elementum Dui Corporation', 'Food Services', 28002, 'small'),
#  ('Elit Curabitur Sed Ltd', 'Advertising', 57877, 'moderate'),
#  ('Erat Incorporated', 'Health, Beauty, and Fitness', 32279, 'moderate'),
#  ('Leo Industries', 'Food Services', 31049, 'moderate'),
#  ('Urna Convallis Erat Ltd', 'Repair Services', 112265, 'huge'),
#  ('Faucibus Morbi Vehicula Company', 'Retail', 120437, 'huge'),
#  ('Nec Mollis Vitae PC', 'Advertising', 53189, 'moderate'),
#  ('Erat LLP', 'Health, Beauty, and Fitness', 123238, 'huge'),
#  ('Curabitur Consequat Foundation', 'Health, Beauty, and Fitness', 105286, 'large'),
#  ('At Risus Company', 'Sports and Recreation', 89576, 'large'),
#  ('Aliquet Odio LLC', 'Maintenance', 75485, 'average'),
#  ('Nulla Ltd', 'Maintenance', 67893, 'moderate'),
#  ('A Enim Suspendisse LLC', 'Technology', 62253, 'moderate'),
#  ('Auctor Non Feugiat Industries', 'Food Services', 101965, 'large'),
#  ('Lorem Sit Amet Corp.', 'Repair Services', 121951, 'huge'),
#  ('Aliquet Magna Corporation', 'Health, Beauty, and Fitness', 37160, 'moderate'),
#  ('Nascetur Ltd', 'Food Services', 113038, 'huge'),
#  ('Turpis Incorporated', 'Retail', 61188, 'moderate'),
#  ('Donec At Industries', 'Maintenance', 123829, 'huge'),
#  ('Tincidunt Orci Quis Inc.', 'Technology', 28888, 'small'),
#  ('Nec Ante Foundation', 'Technology', 118720, 'huge'),
#  ('Penatibus Et Magnis LLP', 'Retail', 75784, 'average'),
#  ('Ipsum Porta Foundation', 'Technology', 19560, 'small'),
#  ('Primis In Company', 'Technology', 147172, 'huge'),
#  ('Massa Foundation', 'Retail', 31385, 'moderate'),
#  ('Vel Vulputate Eu LLP', 'Retail', 123814, 'huge'),
#  ('Arcu Iaculis Enim Associates', 'Sports and Recreation', 111416, 'huge'),
#  ('Orci Ut Sagittis Limited', 'Advertising', 103574, 'large'),
#  ('Maecenas Iaculis Incorporated', 'Repair Services', 38218, 'moderate'),
#  ('Molestie LLP', 'Health, Beauty, and Fitness', 36389, 'moderate'),
#  ('Feugiat Foundation', 'Food Services', 72823, 'average'),
#  ('Maecenas Ornare Egestas Corporation', 'Maintenance', 139000, 'huge'),
#  ('Non Quam Inc.', 'Health, Beauty, and Fitness', 64779, 'moderate'),
#  ('Lacus Nulla Tincidunt Corporation', 'Technology', 145175, 'huge'),
#  ('Cursus Et PC', 'Advertising', 115378, 'huge'),
#  ('Integer Vitae Nibh PC', 'Advertising', 104873, 'large'),
#  ('Eu Tempor Erat LLC', 'Repair Services', 99649, 'large'),
#  ('Tempor Ltd', 'Advertising', 141338, 'huge'),
#  ('Duis Associates', 'Repair Services', 67346, 'moderate'),
#  ('Adipiscing PC', 'Sports and Recreation', 30240, 'moderate'),
#  ('Purus Gravida Sagittis LLC', 'Food Services', 64480, 'moderate'),
#  ('Scelerisque Lorem Ipsum Limited', 'Technology', 18915, 'small'),
#  ('Donec Inc.', 'Food Services', 3910, 'tiny'),
#  ('Posuere Vulputate Limited', 'Advertising', 20251, 'small'),
#  ('Ac Mattis Institute', 'Maintenance', 42313, 'moderate'),
#  ('Ut Lacus Limited', 'Sports and Recreation', 139047, 'huge'),
#  ('Dapibus Rutrum Justo Foundation', 'Food Services', 68338, 'moderate'),
#  ('Metus Vitae Consulting', 'Repair Services', 93016, 'large'),
#  ('Aliquam Fringilla Cursus Consulting', 'Food Services', 131151, 'huge'),
#  ('Sapien Company', 'Maintenance', 96457, 'large'),
#  ('Quis Diam Institute', 'Maintenance', 104420, 'large'),
#  ('Sed Pede Consulting', 'Health, Beauty, and Fitness', 58334, 'moderate'),
#  ('Pede Institute', 'Food Services', 148985, 'huge'),
#  ('Habitant Limited', 'Technology', 50269, 'moderate'),
#  ('Urna Et LLC', 'Food Services', 54894, 'moderate'),
#  ('Sollicitudin Orci Sem Incorporated', 'Technology', 112315, 'huge'),
#  ('Consequat Purus Institute', 'Maintenance', 148169, 'huge'),
#  ('Mi Lorem Vehicula LLP', 'Technology', 18142, 'small'),
#  ('Sem PC', 'Advertising', 144693, 'huge'),
#  ('Sed Pede Institute', 'Repair Services', 68216, 'moderate'),
#  ('Sit Corporation', 'Repair Services', 99491, 'large'),
#  ('Varius Ultrices Associates', 'Technology', 34565, 'moderate'),
#  ('Vel Pede Foundation', 'Advertising', 80756, 'large'),
#  ('Nulla Tincidunt Neque PC', 'Food Services', 41839, 'moderate'),
#  ('Quisque Associates', 'Maintenance', 42381, 'moderate'),
#  ('Convallis Ante Limited', 'Maintenance', 125636, 'huge'),
#  ('Cursus Purus Ltd', 'Repair Services', 56477, 'moderate'),
#  ('Condimentum Corp.', 'Sports and Recreation', 92760, 'large'),
#  ('Lorem Tristique Limited', 'Repair Services', 57799, 'moderate'),
#  ('Morbi Quis Urna Foundation', 'Advertising', 70853, 'average'),
#  ('Auctor Corporation', 'Technology', 98819, 'large'),
#  ('Penatibus Et LLP', 'Repair Services', 91617, 'large'),
#  ('Nunc Quisque PC', 'Retail', 12230, 'small'),
#  ('Nullam Velit Dui Company', 'Retail', 36218, 'moderate'),
#  ('Dictum Augue LLC', 'Maintenance', 141749, 'huge'),
#  ('Id Ante Dictum Company', 'Health, Beauty, and Fitness', 7354, 'tiny'),
#  ('Gravida Nunc Incorporated', 'Advertising', 38595, 'moderate'),
#  ('Aliquet Diam Incorporated', 'Sports and Recreation', 18588, 'small'),
#  ('Curabitur Massa Vestibulum Corporation', 'Sports and Recreation', 92260, 'large'),
#  ('Suspendisse Non Leo Inc.', 'Food Services', 44108, 'moderate'),
#  ('Dui Foundation', 'Technology', 133358, 'huge'),
#  ('Commodo Associates', 'Food Services', 52559, 'moderate'),
#  ('Praesent Eu Nulla Associates', 'Food Services', 57360, 'moderate'),
#  ('Natoque Inc.', 'Health, Beauty, and Fitness', 149636, 'huge'),
#  ('Etiam Imperdiet LLC', 'Food Services', 16649, 'small'),
#  ('Nunc Sit Foundation', 'Food Services', 117741, 'huge'),
#  ('Lacus Aliquam Rutrum Inc.', 'Technology', 78756, 'average'),
#  ('Ac Eleifend Limited', 'Food Services', 93077, 'large'),
#  ('Ante PC', 'Repair Services', 53049, 'moderate'),
#  ('Porta Foundation', 'Food Services', 84969, 'large'),
#  ('Donec Luctus Corp.', 'Maintenance', 98502, 'large'),
#  ('Neque Corp.', 'Technology', 70941, 'average'),
#  ('Non Massa Non Industries', 'Food Services', 73066, 'average'),
#  ('Lacus Incorporated', 'Retail', 49596, 'moderate'),
#  ('Et Netus PC', 'Advertising', 146067, 'huge'),
#  ('Rutrum Non Hendrerit Consulting', 'Food Services', 10541, 'small'),
#  ('Leo Vivamus Nibh Company', 'Sports and Recreation', 35217, 'moderate'),
#  ('Consectetuer Adipiscing LLP', 'Sports and Recreation', 113919, 'huge'),
#  ('Mauris Morbi Non LLC', 'Maintenance', 115256, 'huge'),
#  ('Nunc Sed Limited', 'Advertising', 118596, 'huge'),
#  ('Adipiscing Corporation', 'Maintenance', 78356, 'average'),
#  ('Elit Curabitur Sed Inc.', 'Food Services', 36467, 'moderate'),
#  ('Rutrum Consulting', 'Food Services', 89942, 'large'),
#  ('Non Massa Associates', 'Repair Services', 112983, 'huge'),
#  ('Adipiscing Lobortis Risus Consulting', 'Repair Services', 90391, 'large'),
#  ('Rutrum Corporation', 'Food Services', 141116, 'huge'),
#  ('Pellentesque Tincidunt Tempus Institute', 'Maintenance', 79618, 'average'),
#  ('Eu Eros Nam Consulting', 'Retail', 40782, 'moderate'),
#  ('Hymenaeos Mauris Ut Associates', 'Health, Beauty, and Fitness', 77188, 'average'),
#  ('Non Luctus Sit Industries', 'Technology', 99084, 'large'),
#  ('Cursus Associates', 'Maintenance', 12462, 'small'),
#  ('Amet Luctus Industries', 'Health, Beauty, and Fitness', 3540, 'tiny'),
#  ('Fusce Dolor Corporation', 'Retail', 52003, 'moderate'),
#  ('Lorem Auctor LLC', 'Technology', 132339, 'huge'),
#  ('Magna Ut Tincidunt Industries', 'Technology', 59527, 'moderate'),
#  ('Turpis Non Enim Incorporated', 'Technology', 47467, 'moderate'),
#  ('In Scelerisque Company', 'Food Services', 53869, 'moderate'),
#  ('Ipsum Suspendisse LLP', 'Health, Beauty, and Fitness', 147471, 'huge'),
#  ('Nunc In At Corporation', 'Repair Services', 31493, 'moderate'),
#  ('Pretium Aliquet Metus Associates', 'Retail', 114707, 'huge'),
#  ('Lectus Institute', 'Sports and Recreation', 131684, 'huge'),
#  ('Cursus A Enim Ltd', 'Technology', 69708, 'moderate'),
#  ('Lorem Luctus Ut Institute', 'Sports and Recreation', 20041, 'small'),
#  ('Dui Quis Corp.', 'Food Services', 109849, 'large'),
#  ('Quis Pede Praesent LLC', 'Advertising', 69312, 'moderate'),
#  ('Mauris Quis Turpis Corporation', 'Health, Beauty, and Fitness', 120776, 'huge'),
#  ('Quisque Libero Lacus Industries', 'Advertising', 121195, 'huge'),
#  ('Aliquet PC', 'Health, Beauty, and Fitness', 99262, 'large'),
#  ('Condimentum LLP', 'Maintenance', 32429, 'moderate'),
#  ('Purus In Molestie Institute', 'Advertising', 120935, 'huge'),
#  ('Cras Company', 'Maintenance', 60398, 'moderate'),
#  ('Mauris Magna LLC', 'Repair Services', 61664, 'moderate'),
#  ('Turpis Egestas Fusce Associates', 'Repair Services', 128574, 'huge'),
#  ('Cras Lorem Company', 'Retail', 82023, 'large'),
#  ('Cras Corporation', 'Maintenance', 136626, 'huge'),
#  ('Penatibus Et Consulting', 'Food Services', 9849, 'tiny'),
#  ('Donec Consectetuer Mauris LLP', 'Repair Services', 132138, 'huge'),
#  ('Sociosqu Ad LLP', 'Sports and Recreation', 4768, 'tiny'),
#  ('Ac Tellus Consulting', 'Technology', 135957, 'huge'),
#  ('Donec Felis Incorporated', 'Technology', 139878, 'huge'),
#  ('Odio Tristique Pharetra Incorporated', 'Food Services', 63000, 'moderate'),
#  ('Nunc Corp.', 'Repair Services', 149089, 'huge'),
#  ('Eu Tempor Associates', 'Repair Services', 148155, 'huge'),
#  ('Orci Limited', 'Technology', 128338, 'huge'),
#  ('Neque Associates', 'Technology', 112274, 'huge'),
#  ('Tellus PC', 'Sports and Recreation', 101611, 'large'),
#  ('Amet Orci Industries', 'Technology', 141042, 'huge'),
#  ('Ante LLC', 'Technology', 143898, 'huge'),
#  ('Nullam Lobortis Quam Incorporated', 'Food Services', 147295, 'huge'),
#  ('Amet Company', 'Sports and Recreation', 143113, 'huge'),
#  ('Quam Vel Industries', 'Sports and Recreation', 76924, 'average'),
#  ('Fermentum Vel Foundation', 'Repair Services', 17424, 'small'),
#  ('Et Ipsum Associates', 'Food Services', 16287, 'small'),
#  ('Orci Consectetuer Consulting', 'Health, Beauty, and Fitness', 133918, 'huge'),
#  ('Sem Inc.', 'Sports and Recreation', 102576, 'large'),
#  ('Egestas Sed Pharetra Company', 'Advertising', 62157, 'moderate'),
#  ('Sed Leo Associates', 'Food Services', 25952, 'small'),
#  ('In Lobortis Company', 'Retail', 15505, 'small'),
#  ('Vitae Posuere Corporation', 'Health, Beauty, and Fitness', 118290, 'huge'),
#  ('Lectus LLC', 'Repair Services', 141612, 'huge'),
#  ('Id Ante PC', 'Retail', 16077, 'small'),
#  ('Dapibus Id Consulting', 'Food Services', 139764, 'huge'),
#  ('Aenean Eget Industries', 'Advertising', 16905, 'small'),
#  ('Egestas A Company', 'Technology', 138029, 'huge'),
#  ('Donec Associates', 'Maintenance', 131563, 'huge'),
#  ('Odio Etiam Ligula Associates', 'Advertising', 127882, 'huge'),
#  ('Dolor Egestas Rhoncus LLP', 'Food Services', 110188, 'huge'),
#  ('Enim Etiam Incorporated', 'Retail', 64366, 'moderate'),
#  ('Ipsum PC', 'Technology', 71967, 'average'),
#  ('Nec Corp.', 'Sports and Recreation', 79900, 'average'),
#  ('Iaculis Enim Sit Corp.', 'Technology', 21943, 'small'),
#  ('Nec Eleifend Non Limited', 'Food Services', 5707, 'tiny'),
#  ('Arcu Sed Eu LLP', 'Food Services', 47499, 'moderate'),
#  ('Ante Consulting', 'Advertising', 142521, 'huge'),
#  ('Nunc Limited', 'Health, Beauty, and Fitness', 120181, 'huge'),
#  ('Orci Foundation', 'Retail', 146301, 'huge'),
#  ('Et LLC', 'Repair Services', 50373, 'moderate'),
#  ('Metus LLC', 'Technology', 104813, 'large'),
#  ('Sed Eu Nibh Foundation', 'Repair Services', 3137, 'tiny'),
#  ('Nisi Sem Semper Institute', 'Food Services', 88673, 'large'),
#  ('Aliquet Phasellus Fermentum Institute', 'Repair Services', 117832, 'huge'),
#  ('Lorem Donec Elementum Corporation', 'Food Services', 71763, 'average'),
#  ('Scelerisque Sed Sapien Inc.', 'Sports and Recreation', 18565, 'small'),
#  ('Enim Inc.', 'Food Services', 132242, 'huge'),
#  ('Sed Pharetra Felis Company', 'Food Services', 33063, 'moderate'),
#  ('Sed Eget Industries', 'Sports and Recreation', 27263, 'small'),
#  ('Iaculis Enim Consulting', 'Food Services', 95331, 'large'),
#  ('Sit Amet Ornare LLP', 'Repair Services', 103454, 'large'),
#  ('Erat Eget Associates', 'Maintenance', 67505, 'moderate'),
#  ('Justo Faucibus Lectus LLP', 'Advertising', 118924, 'huge'),
#  ('Mauris Sagittis Placerat Institute', 'Sports and Recreation', 47998, 'moderate'),
#  ('Sed Nulla Consulting', 'Repair Services', 38573, 'moderate'),
#  ('Donec Tempor Limited', 'Retail', 26387, 'small')]

# %% [markdown]
# # Sub-Question 2
#
# __Business Request:__ _Looking at the number of grant applications received, find information regarding the owners of these small businesses. Specifically, identify how many of each ethnic group entrepreneurs classify with and return the numbers for each._
#
# __Question:__ _How many business owners who applied for a grant identified with each ethnic group? Which ethnic group did we receive the most grant applications from? Present the results from the largest ethnic group represented in the current applications._
#
# __Business Justification:__ _JP Morgan Chase & Co. Business Resource Groups, which cater to underserved communities, would like to share information relating to this data in their bi-weekly newsletter and update public and private audiences._
#
# SQL Features Used: _VIEW, CONCAT, JOIN, GROUP BY, ORDER BY, COUNT_

# %%
# %%sql
# CREATE OR REPLACE VIEW Entrepreneur_Details AS (
#     SELECT
#         CONCAT(o.first_name,' ', o.last_name) AS Entrepreneur,
#         g.classification AS Gender_Identity,
#         e.ethnic_group AS Ethnicity
#     FROM Owners_GrantApplicants o
#     JOIN GenderIdentity g
#         ON o.gender_id = g.gender_id
#     JOIN EthnicIdentity e
#         ON o.ethnic_id = e.ethnic_id
#     GROUP BY o.owner_grant_id
#     ORDER BY Entrepreneur
# );
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM Entrepreneur_Details;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 400 rows affected.
# [('Aaron Guy', 'Female', 'Asian'),
#  ('Aaron Salinas', 'Male', 'Asian'),
#  ('Abraham Baker', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Adrian Alexander', 'Male', 'Asian'),
#  ('Aidan Park', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Akeem Jones', 'Male', 'American Indian or Alaska Native'),
#  ('Aladdin Snider', 'Female', 'Black or African American'),
#  ('Alan Acosta', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Alan Powers', 'Female', 'Black or African American'),
#  ('Alea Dawson', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Alexis Robbins', 'Female', 'American Indian or Alaska Native'),
#  ('Ali Hardy', 'Male', 'Hispanic or Latinx'),
#  ('Alika Rodgers', 'Male', 'Middle Eastern'),
#  ('Amal Adams', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Amal Graham', 'Non-Binary', 'Asian'),
#  ('Amela Watts', 'Other', 'Black or African American'),
#  ('Amir Bruce', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Amir Figueroa', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Amos Weaver', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Anthony Cooke', 'Female', 'Hispanic or Latinx'),
#  ('Anthony Dennis', 'Other', 'Middle Eastern'),
#  ('Arden Finley', 'Female', 'Hispanic or Latinx'),
#  ('Ariel Molina', 'Female', 'Black or African American'),
#  ('Armand Kim', 'Non-Binary', 'Middle Eastern'),
#  ('Arthur Allison', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Ashton Workman', 'Male', 'Black or African American'),
#  ('Aspen Lynn', 'Female', 'Black or African American'),
#  ('Aubrey Cash', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('August Serrano', 'Female', 'Black or African American'),
#  ('Austin Roberson', 'Non-Binary', 'Black or African American'),
#  ('Ava Oneal', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Barclay Stout', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Barry Bruce', 'Other', 'Hispanic or Latinx'),
#  ('Basil Cline', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Beatrice Ramsey', 'Female', 'Middle Eastern'),
#  ('Benedict Sweeney', 'Female', 'Hispanic or Latinx'),
#  ('Benjamin Rodriguez', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Berk Haley', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Bethany Floyd', 'Male', 'Hispanic or Latinx'),
#  ('Bethany Wallace', 'Other', 'Middle Eastern'),
#  ('Bianca Russo', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Blaine Justice', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Blair Holden', 'Other', 'Middle Eastern'),
#  ('Blake Larsen', 'Female', 'Middle Eastern'),
#  ('Blaze Dennis', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Blythe Cox', 'Female', 'Middle Eastern'),
#  ('Boris Henry', 'Female', 'American Indian or Alaska Native'),
#  ('Brady Albert', 'Female', 'American Indian or Alaska Native'),
#  ('Branden Bradshaw', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Branden Carr', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Brendan Pratt', 'Other', 'Black or African American'),
#  ('Brian Smith', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Brianna Pennington', 'Male', 'Asian'),
#  ('Brock Bowers', 'Non-Binary', 'Middle Eastern'),
#  ('Bruno Charles', 'Female', 'Hispanic or Latinx'),
#  ('Bryar Greene', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Brynne Lawson', 'Female', 'American Indian or Alaska Native'),
#  ('Buffy Owen', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Burke Foster', 'Other', 'American Indian or Alaska Native'),
#  ('Caldwell Murray', 'Female', 'Asian'),
#  ('Caleb Fuentes', 'Other', 'Hispanic or Latinx'),
#  ('Cameron Bright', 'Other', 'Asian'),
#  ('Cameron Nichols', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Camilla Flowers', 'Non-Binary', 'Middle Eastern'),
#  ('Carol Rojas', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Carter Robbins', 'Male', 'American Indian or Alaska Native'),
#  ('Caryn Nicholson', 'Non-Binary', 'Middle Eastern'),
#  ('Cassandra Pacheco', 'Other', 'American Indian or Alaska Native'),
#  ('Castor Reese', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Chanda Francis', 'Other', 'Middle Eastern'),
#  ('Charde Reese', 'Male', 'Asian'),
#  ('Charde Travis', 'Other', 'Hispanic or Latinx'),
#  ('Charissa Tanner', 'Female', 'Hispanic or Latinx'),
#  ('Charles Graham', 'Male', 'Asian'),
#  ('Chiquita Carroll', 'Male', 'Hispanic or Latinx'),
#  ('Clare Carr', 'Male', 'Middle Eastern'),
#  ('Colby Huff', 'Male', 'Black or African American'),
#  ('Conan Bullock', 'Female', 'Middle Eastern'),
#  ('Conan Sparks', 'Other', 'Black or African American'),
#  ('Connor Goff', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Constance Conner', 'Other', 'American Indian or Alaska Native'),
#  ('Cooper Mayer', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Damian French', 'Female', 'Black or African American'),
#  ('Dana Mason', 'Other', 'Black or African American'),
#  ('Dara Hunter', 'Female', 'Hispanic or Latinx'),
#  ('Darius Morgan', 'Other', 'Middle Eastern'),
#  ('Darryl Castillo', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Darryl Waters', 'Female', 'Hispanic or Latinx'),
#  ('Daryl Dunlap', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Dean Lowe', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Deborah Acosta', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Debra Erickson', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Demetrius Webb', 'Other', 'Hispanic or Latinx'),
#  ('Dennis Cherry', 'Other', 'Asian'),
#  ('Denton Bright', 'Male', 'Black or African American'),
#  ('Desirae Snow', 'Non-Binary', 'Black or African American'),
#  ('Devin Daugherty', 'Female', 'Hispanic or Latinx'),
#  ('Diana Molina', 'Non-Binary', 'Middle Eastern'),
#  ('Dieter Holman', 'Male', 'Black or African American'),
#  ('Dominic Little', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Dominique Duncan', 'Non-Binary', 'Middle Eastern'),
#  ('Donna Koch', 'Female', 'Hispanic or Latinx'),
#  ('Dora Everett', 'Female', 'Asian'),
#  ('Dorian Morrison', 'Male', 'Middle Eastern'),
#  ('Doris Snow', 'Other', 'Black or African American'),
#  ('Driscoll Waller', 'Non-Binary', 'Black or African American'),
#  ('Dustin Sharpe', 'Female', 'Asian'),
#  ('Edan Howe', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Eleanor Mcintosh', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Elijah Everett', 'Female', 'Hispanic or Latinx'),
#  ('Elizabeth Leon', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Elliott Harmon', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Elmo Humphrey', 'Other', 'Middle Eastern'),
#  ('Elton Jefferson', 'Non-Binary', 'Asian'),
#  ('Elvis Stanley', 'Non-Binary', 'Middle Eastern'),
#  ('Emery Yang', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Emily Atkins', 'Male', 'Asian'),
#  ('Emmanuel Peck', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Erich Sellers', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Eve Gilmore', 'Male', 'American Indian or Alaska Native'),
#  ('Ezekiel Estrada', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Faith Boone', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Fallon Arnold', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Ferdinand Hardy', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Fiona French', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Fletcher Anderson', 'Other', 'American Indian or Alaska Native'),
#  ('Forrest Wilder', 'Male', 'Black or African American'),
#  ('Fritz Lewis', 'Male', 'Black or African American'),
#  ('Fuller Baird', 'Male', 'Asian'),
#  ('Fuller Patel', 'Female', 'Asian'),
#  ('Fulton Sargent', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Galena Howe', 'Female', 'Asian'),
#  ('Garrison Rios', 'Female', 'Middle Eastern'),
#  ('Garth Hutchinson', 'Male', 'Asian'),
#  ('Gavin Gross', 'Other', 'Hispanic or Latinx'),
#  ('Gay Conrad', 'Male', 'Middle Eastern'),
#  ('Gay Pearson', 'Non-Binary', 'Asian'),
#  ('Genevieve Rocha', 'Female', 'Black or African American'),
#  ('Geoffrey Anderson', 'Female', 'Black or African American'),
#  ('Ginger Sutton', 'Female', 'Hispanic or Latinx'),
#  ('Grady Hoover', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Graiden Marsh', 'Male', 'Middle Eastern'),
#  ('Gray Juarez', 'Non-Binary', 'Middle Eastern'),
#  ('Guy Carter', 'Male', 'Black or African American'),
#  ('Gwendolyn Copeland', 'Other', 'Hispanic or Latinx'),
#  ('Halee Hodge', 'Other', 'Black or African American'),
#  ('Hamilton Leblanc', 'Male', 'Asian'),
#  ('Hamilton Nelson', 'Female', 'American Indian or Alaska Native'),
#  ('Hamilton Nichols', 'Non-Binary', 'Black or African American'),
#  ('Hamish Sawyer', 'Non-Binary', 'Asian'),
#  ('Hannah Becker', 'Male', 'Hispanic or Latinx'),
#  ('Harding Levine', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Hashim Adams', 'Female', 'Hispanic or Latinx'),
#  ('Hayes Price', 'Other', 'Asian'),
#  ('Hayfa Spencer', 'Non-Binary', 'Middle Eastern'),
#  ('Hayley Noble', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Hedda Goodman', 'Other', 'Middle Eastern'),
#  ('Hedda Mcgee', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Herman Bird', 'Female', 'Black or African American'),
#  ('Herman Short', 'Non-Binary', 'Middle Eastern'),
#  ('Hermione Harrell', 'Other', 'Middle Eastern'),
#  ('Herrod Boone', 'Non-Binary', 'Middle Eastern'),
#  ('Hilary Case', 'Non-Binary', 'Asian'),
#  ('Hiram Riggs', 'Male', 'American Indian or Alaska Native'),
#  ('Holmes Wolf', 'Other', 'Black or African American'),
#  ('Honorato Hicks', 'Non-Binary', 'Middle Eastern'),
#  ('Hop Rowland', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Hope Park', 'Other', 'American Indian or Alaska Native'),
#  ('Hoyt Buchanan', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Hyacinth Chaney', 'Other', 'Black or African American'),
#  ('Ignacia Miles', 'Other', 'Middle Eastern'),
#  ('Ignatius Wolf', 'Other', 'Middle Eastern'),
#  ('Iliana Glenn', 'Female', 'Black or African American'),
#  ('Illiana Burns', 'Female', 'American Indian or Alaska Native'),
#  ('Imani Hardy', 'Male', 'Asian'),
#  ('Imani Stokes', 'Other', 'Black or African American'),
#  ('Imogene Summers', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('India Wright', 'Female', 'Black or African American'),
#  ('Indira Kemp', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Irene Best', 'Male', 'American Indian or Alaska Native'),
#  ('Iris Nunez', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Isaac Lester', 'Female', 'Asian'),
#  ('Isabelle Booker', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Isadora Roberts', 'Non-Binary', 'Black or African American'),
#  ('Isaiah Koch', 'Female', 'Middle Eastern'),
#  ('Ishmael Koch', 'Non-Binary', 'Middle Eastern'),
#  ('Ivory Hampton', 'Male', 'Middle Eastern'),
#  ('Jacob Torres', 'Non-Binary', 'Middle Eastern'),
#  ('Jada Sherman', 'Female', 'Hispanic or Latinx'),
#  ('Jamal May', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Jamalia Freeman', 'Male', 'Black or African American'),
#  ('Jamalia Randall', 'Other', 'Hispanic or Latinx'),
#  ('Jana Elliott', 'Non-Binary', 'Asian'),
#  ('Jane David', 'Other', 'Hispanic or Latinx'),
#  ('Jared Cervantes', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Jason Carlson', 'Male', 'Middle Eastern'),
#  ('Jennifer Wagner', 'Male', 'Hispanic or Latinx'),
#  ('Jeremy Barr', 'Male', 'Black or African American'),
#  ('Jerry Castro', 'Female', 'Middle Eastern'),
#  ('Jerry Haley', 'Female', 'Middle Eastern'),
#  ('Jescie Freeman', 'Male', 'Middle Eastern'),
#  ('Jesse Carlson', 'Male', 'American Indian or Alaska Native'),
#  ('Jin Burt', 'Male', 'Hispanic or Latinx'),
#  ('Joel Barr', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Jolene Wallace', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Judah Townsend', 'Other', 'Black or African American'),
#  ('Kameko Carver', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Kameko Castillo', 'Other', 'Hispanic or Latinx'),
#  ('Karen Boyd', 'Male', 'Middle Eastern'),
#  ('Karen Nixon', 'Non-Binary', 'Middle Eastern'),
#  ('Karyn Carr', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Karyn Osborne', 'Non-Binary', 'Asian'),
#  ('Katell Holmes', 'Female', 'American Indian or Alaska Native'),
#  ('Kato Bowers', 'Other', 'Hispanic or Latinx'),
#  ('Keane Blevins', 'Other', 'American Indian or Alaska Native'),
#  ('Keefe Haney', 'Female', 'Hispanic or Latinx'),
#  ('Keelie Hawkins', 'Female', 'Black or African American'),
#  ('Keith Decker', 'Male', 'Black or African American'),
#  ('Kelly Frazier', 'Non-Binary', 'Asian'),
#  ('Kelsie Kelly', 'Male', 'Hispanic or Latinx'),
#  ('Kendall Hogan', 'Non-Binary', 'Middle Eastern'),
#  ('Kendall Lucas', 'Other', 'Middle Eastern'),
#  ('Kenneth Baxter', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Kermit Lopez', 'Female', 'Hispanic or Latinx'),
#  ('Kessie Jarvis', 'Male', 'Black or African American'),
#  ('Kevin Pollard', 'Male', 'Middle Eastern'),
#  ('Kiayada Cervantes', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Kirestin Scott', 'Non-Binary', 'Black or African American'),
#  ('Kirk Dickson', 'Other', 'American Indian or Alaska Native'),
#  ('Kirsten Duran', 'Other', 'Hispanic or Latinx'),
#  ('Kristen Harper', 'Male', 'Asian'),
#  ('Kyle Donovan', 'Male', 'Middle Eastern'),
#  ('Kyle Salinas', 'Female', 'Hispanic or Latinx'),
#  ('Kylee Waller', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Kyra Hart', 'Male', 'Middle Eastern'),
#  ('Laith Mcclain', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Lamar Tyson', 'Non-Binary', 'Asian'),
#  ('Larissa Knight', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Lars Higgins', 'Other', 'Black or African American'),
#  ('Lars Robles', 'Male', 'Black or African American'),
#  ('Latifah Lynch', 'Female', 'Middle Eastern'),
#  ('Laurel Page', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Lavinia Wilcox', 'Non-Binary', 'Asian'),
#  ('Lee Herman', 'Female', 'Hispanic or Latinx'),
#  ('Leigh Huber', 'Female', 'Black or African American'),
#  ('Leilani Wilcox', 'Non-Binary', 'Black or African American'),
#  ('Levi Bird', 'Other', 'Middle Eastern'),
#  ('Levi Workman', 'Female', 'Middle Eastern'),
#  ('Lewis Macias', 'Non-Binary', 'Black or African American'),
#  ('Lewis Sanford', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Liberty Mccarty', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Liberty Terrell', 'Other', 'Asian'),
#  ('Lila Ratliff', 'Female', 'American Indian or Alaska Native'),
#  ('Lillith Oliver', 'Other', 'Asian'),
#  ('Linus Murphy', 'Non-Binary', 'Asian'),
#  ('Linus Prince', 'Male', 'Hispanic or Latinx'),
#  ('Lisandra Drake', 'Female', 'Asian'),
#  ('Logan Kaufman', 'Female', 'Hispanic or Latinx'),
#  ('Lucius Burnett', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Luke Maxwell', 'Male', 'Hispanic or Latinx'),
#  ('Macey Lewis', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Madonna Simmons', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Magee Jarvis', 'Non-Binary', 'Asian'),
#  ('Maia Jefferson', 'Other', 'Asian'),
#  ('Malachi Dickerson', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Mannix Bullock', 'Female', 'Middle Eastern'),
#  ('Mara Chan', 'Female', 'Black or African American'),
#  ('Maris Browning', 'Male', 'American Indian or Alaska Native'),
#  ('Maris Reeves', 'Other', 'Black or African American'),
#  ('Maris Trujillo', 'Other', 'Asian'),
#  ('Maris Villarreal', 'Female', 'Black or African American'),
#  ('Mark Frye', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Martin Tillman', 'Non-Binary', 'Black or African American'),
#  ('Martina Terry', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Melanie Calhoun', 'Female', 'Hispanic or Latinx'),
#  ('Melodie Stein', 'Other', 'Asian'),
#  ('Melyssa Avila', 'Male', 'American Indian or Alaska Native'),
#  ('Melyssa Ewing', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Merrill Gonzalez', 'Male', 'Asian'),
#  ('Mohammad Sloan', 'Male', 'Hispanic or Latinx'),
#  ('Molly Bailey', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Morgan Bauer', 'Female', 'Asian'),
#  ('Mufutau Ewing', 'Female', 'Asian'),
#  ('Mufutau Harrell', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Myles Harper', 'Other', 'Middle Eastern'),
#  ('Naida Bullock', 'Other', 'Hispanic or Latinx'),
#  ('Nash Mccullough', 'Male', 'Black or African American'),
#  ('Natalie Aguirre', 'Female', 'Black or African American'),
#  ('Nathan Whitfield', 'Female', 'Black or African American'),
#  ('Nehru Cummings', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Nicholas Norris', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Nigel Gallegos', 'Non-Binary', 'Middle Eastern'),
#  ('Noah Douglas', 'Other', 'Hispanic or Latinx'),
#  ('Noah Hobbs', 'Other', 'Hispanic or Latinx'),
#  ('Noelle Norton', 'Female', 'Asian'),
#  ('Nola Carlson', 'Other', 'Asian'),
#  ('Nolan Payne', 'Other', 'Hispanic or Latinx'),
#  ('Odessa Huber', 'Male', 'American Indian or Alaska Native'),
#  ('Odessa Riddle', 'Female', 'American Indian or Alaska Native'),
#  ('Odette Lee', 'Non-Binary', 'Black or African American'),
#  ('Oleg Hurst', 'Non-Binary', 'Asian'),
#  ('Ori Mcgee', 'Female', 'Hispanic or Latinx'),
#  ('Orli Warren', 'Other', 'Hispanic or Latinx'),
#  ('Orson Glover', 'Female', 'Black or African American'),
#  ('Otto Blankenship', 'Non-Binary', 'Middle Eastern'),
#  ('Patricia Contreras', 'Non-Binary', 'Middle Eastern'),
#  ('Patricia Kirkland', 'Other', 'American Indian or Alaska Native'),
#  ('Penelope Johnson', 'Female', 'Middle Eastern'),
#  ('Peter Alston', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Phelan Hahn', 'Male', 'American Indian or Alaska Native'),
#  ('Phillip Dillard', 'Female', 'American Indian or Alaska Native'),
#  ('Phoebe Willis', 'Other', 'Hispanic or Latinx'),
#  ('Plato Patterson', 'Other', 'Black or African American'),
#  ('Preston Gallegos', 'Other', 'Black or African American'),
#  ('Preston Price', 'Female', 'Black or African American'),
#  ('Quintessa Hyde', 'Female', 'American Indian or Alaska Native'),
#  ('Rafael Aguilar', 'Male', 'American Indian or Alaska Native'),
#  ('Rajah Cooke', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Rama Lucas', 'Female', 'Middle Eastern'),
#  ('Rashad Mckee', 'Male', 'Asian'),
#  ('Ray Le', 'Female', 'Black or African American'),
#  ('Raymond Carlson', 'Other', 'Asian'),
#  ('Reece Sampson', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Regan Freeman', 'Male', 'Black or African American'),
#  ('Regan Wolfe', 'Female', 'Asian'),
#  ('Reuben Burris', 'Other', 'Asian'),
#  ('Rina Fields', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Risa Cameron', 'Female', 'American Indian or Alaska Native'),
#  ('Risa Dalton', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Roanna Stephens', 'Male', 'Asian'),
#  ('Robin Valdez', 'Male', 'American Indian or Alaska Native'),
#  ('Rooney Lee', 'Other', 'Black or African American'),
#  ('Ross Nichols', 'Female', 'American Indian or Alaska Native'),
#  ('Russell Wolfe', 'Male', 'Hispanic or Latinx'),
#  ('Samuel Lott', 'Female', 'Black or African American'),
#  ('Sarah Mcmahon', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Sawyer Osborn', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('September Hale', 'Male', 'Black or African American'),
#  ('Serena Sexton', 'Male', 'American Indian or Alaska Native'),
#  ('Shad Green', 'Female', 'Hispanic or Latinx'),
#  ('Shana Macdonald', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Shellie Rivers', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Shelly Gilbert', 'Male', 'American Indian or Alaska Native'),
#  ('Signe Roman', 'Male', 'Asian'),
#  ('Silas Stevenson', 'Other', 'Asian'),
#  ('Steel Sampson', 'Female', 'Middle Eastern'),
#  ('Sybil Moss', 'Male', 'Asian'),
#  ('Sydney Cortez', 'Male', 'Middle Eastern'),
#  ('Sylvester Head', 'Male', 'American Indian or Alaska Native'),
#  ('Talon Owens', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Tamekah Wilkerson', 'Female', 'American Indian or Alaska Native'),
#  ('Tanisha Riggs', 'Male', 'Middle Eastern'),
#  ('Tara Goodwin', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Tate Gamble', 'Female', 'Middle Eastern'),
#  ('Teegan Villarreal', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Thane Hebert', 'Male', 'Black or African American'),
#  ('Travis Vaughan', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Ulla Harper', 'Non-Binary', 'Middle Eastern'),
#  ('Ulric Browning', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Ulric Mckinney', 'Female', 'Native Hawaiian or Other Pacific Islander'),
#  ('Ulysses Stokes', 'Female', 'American Indian or Alaska Native'),
#  ('Upton Rojas', 'Male', 'Middle Eastern'),
#  ('Uriah Koch', 'Female', 'Black or African American'),
#  ('Uriel Wright', 'Male', 'Hispanic or Latinx'),
#  ('Urielle Underwood', 'Male', 'Asian'),
#  ('Ursula Carroll', 'Other', 'American Indian or Alaska Native'),
#  ('Ursula Casey', 'Female', 'Hispanic or Latinx'),
#  ('Valentine Wiggins', 'Other', 'Middle Eastern'),
#  ('Vernon Morrison', 'Other', 'American Indian or Alaska Native'),
#  ('Veronica Harding', 'Other', 'Hispanic or Latinx'),
#  ('Victor Guerrero', 'Female', 'Asian'),
#  ('Victoria Maynard', 'Male', 'Black or African American'),
#  ('Vielka Terrell', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Walker Hayden', 'Other', 'Hispanic or Latinx'),
#  ('Wallace Holland', 'Other', 'Hispanic or Latinx'),
#  ('Wang Pickett', 'Other', 'Black or African American'),
#  ('Warren Moses', 'Male', 'Hispanic or Latinx'),
#  ('Wayne Bailey', 'Non-Binary', 'Asian'),
#  ('Wayne Blake', 'Female', 'American Indian or Alaska Native'),
#  ('Winter Bradshaw', 'Non-Binary', 'Hispanic or Latinx'),
#  ('Wyatt Combs', 'Female', 'Hispanic or Latinx'),
#  ('Wynter Haley', 'Female', 'American Indian or Alaska Native'),
#  ('Wynter Matthews', 'Non-Binary', 'Middle Eastern'),
#  ('Wyoming Rosario', 'Non-Binary', 'Black or African American'),
#  ('Xander Livingston', 'Non-Binary', 'American Indian or Alaska Native'),
#  ('Xanthus Zimmerman', 'Other', 'Native Hawaiian or Other Pacific Islander'),
#  ('Xaviera Bender', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Yardley Nolan', 'Other', 'Hispanic or Latinx'),
#  ('Yasir Obrien', 'Male', 'American Indian or Alaska Native'),
#  ('Yetta Reilly', 'Other', 'American Indian or Alaska Native'),
#  ('Yoko Patrick', 'Other', 'American Indian or Alaska Native'),
#  ('Yoshi Conway', 'Other', 'Asian'),
#  ('Yuli Barber', 'Other', 'Middle Eastern'),
#  ('Yvonne Jimenez', 'Male', 'Native Hawaiian or Other Pacific Islander'),
#  ('Zena Clay', 'Other', 'Middle Eastern'),
#  ('Zenaida Hahn', 'Male', 'Hispanic or Latinx'),
#  ('Zenaida Owen', 'Male', 'Asian'),
#  ('Zia Guy', 'Other', 'American Indian or Alaska Native'),
#  ('Zia Sandoval', 'Non-Binary', 'Native Hawaiian or Other Pacific Islander'),
#  ('Zoe Strong', 'Other', 'Black or African American')]

# %%
# %%sql
# SELECT
#     Ethnicity,
#     COUNT(*) AS Entrepreneur_count
# FROM Entrepreneur_Details
# GROUP BY Ethnicity
# ORDER BY Entrepreneur_count DESC;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 6 rows affected.
# [('Native Hawaiian or Other Pacific Islander', 73),
#  ('Hispanic or Latinx', 70),
#  ('Black or African American', 67),
#  ('Middle Eastern', 67),
#  ('American Indian or Alaska Native', 65),
#  ('Asian', 58)]

# %% [markdown]
# # Sub-Question 3
#
# __Business Request:__ _The team would like to view similar results as the previous query, except this time identify how many entrepreneurs classify with each gender identity._
#
# __Question:__ _How many business owners classify with each gender identity? Which gender identity did we receieve the most grant applications from? Present the results from the largest group represented in the current applications. Sort by each group classification._
#
# __Business Justification:__ _The team wants to know what the majority is amongst entrepreneurs who applied for a grant for statistic purposes._
#
# SQL Features Used: _COUNT, GROUP BY, ORDER BY_

# %%
 # %%sql
SELECT
    Gender_Identity,
    COUNT(*) AS gender_count
FROM Entrepreneur_Details
GROUP BY Gender_Identity
ORDER BY gender_count DESC;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 4 rows affected.
# [('Female', 103), ('Other', 103), ('Male', 98), ('Non-Binary', 96)]

# %% [markdown]
# ## Recommendation:
#
# Observing the number of results received, I would say that thus far we see a good amount of representation-- in regards to industry, ethnicity, and gender identity--within businesses who have applied to receive a grant from JP Morgan. My recommendation would be for analysts to continue their processes in inviting more entrepreneurs of color to apply before the application period closes. I believe creating CTEs were a good option in retaining information and being able to reference updated versions for future inquiries. I'd recommend that analysts identify and keep tabs on how many grants they approve going forward and in what amounts, so they stay on budget with their reserve.

# %% [markdown]
# # Exploratory Query - 1
#
# __Business Request:__ _Your manager at JP Morgan is having trouble sorting through recent loan applications. They know they received a lot of interested businesses; however, they feel like they can't interpret the data provided. Your manager would like for you classify the loan amounts requested from California businesses by ranging their values._
#
# __Question:__ _How many California businesses applied for a loan? How much are they requesting? Provide a distinctive group range for specified loan amounts._
#
# __Business Justification:__ _This helps them identify the size of loans and gage the specified amounts via their loan range classification._
#
# SQL Features Used: _CASE_

# %%
# %%sql
# SELECT
#     business_name,
#     loan_amount,
#     CASE
#         WHEN loan_amount = '$150,000-350,000' THEN 'minimum loan'
#         WHEN loan_amount = '$350,000-1 million' THEN 'small loan'
#         WHEN loan_amount = '$1-2 million' THEN 'median loan'
#         WHEN loan_amount = '$2-5 million' THEN 'above average loan'
#         WHEN loan_amount = '$5-10 million' THEN 'maximum loan'
#     END AS loan_range
# FROM CaliforniaLoanApplication;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 300 rows affected.
# [('#1 NORTH AMERICAN INVESTMENT COMPANY, LLC', '$150,000-350,000', 'minimum loan'),
#  ("'OUR' CHILD DAY CARE", '$150,000-350,000', 'minimum loan'),
#  ('(A) TOOL SHED, INC.', '$1-2 million', 'median loan'),
#  ('@HEALTH MEDICAL MANAGEMENT INC.; A DELAWARE CORPORATION', '$350,000-1 million', 'small loan'),
#  ('@X1 COMPUTER CORPORATION', '$150,000-350,000', 'minimum loan'),
#  ('@YOURGATE LLC', '$350,000-1 million', 'small loan'),
#  ('[24]7.AI, INC.', '$5-10 million', 'maximum loan'),
#  ('0CHAIN LLC', '$150,000-350,000', 'minimum loan'),
#  ('1 GUN RANCH LP', '$150,000-350,000', 'minimum loan'),
#  ('1 INC.', '$150,000-350,000', 'minimum loan'),
#  ('1 IOTA PRODUCTIONS, LLC', '$350,000-1 million', 'small loan'),
#  ('1 METHOD LLC', '$150,000-350,000', 'minimum loan'),
#  ('1 STOP POOL PROS', '$150,000-350,000', 'minimum loan'),
#  ('1 STOP POOL PROS #1, INC.', '$150,000-350,000', 'minimum loan'),
#  ('1-800 WINESHOP.COM INC.', '$350,000-1 million', 'small loan'),
#  ('1-800-BOLLARD, INC.', '$150,000-350,000', 'minimum loan'),
#  ('1-888-4-ABATEMENT, INC., A CALIFORNIA CORPORATION', '$350,000-1 million', 'small loan'),
#  ('1. CONQUEST INDUSTRIES, INC. 2. LIBERTY MFG., INC.', '$150,000-350,000', 'minimum loan'),
#  ('10 FOLD COMMUNICATIONS, INC.', '$350,000-1 million', 'small loan'),
#  ('10 MINUTE FITNESS, INC', '$150,000-350,000', 'minimum loan'),
#  ('10,000 DEGREES', '$1-2 million', 'median loan'),
#  ('10/40 WINDOW, INC.', '$150,000-350,000', 'minimum loan'),
#  ('100 DREAMS INC.', '$350,000-1 million', 'small loan'),
#  ('100 OCEANGATE, LLC', '$150,000-350,000', 'minimum loan'),
#  ('100 PERCENT CONCRETE INC', '$150,000-350,000', 'minimum loan'),
#  ('100 VAN NESS LLC', '$150,000-350,000', 'minimum loan'),
#  ('100% SPEEDLAB, LLC', '$350,000-1 million', 'small loan'),
#  ('1000 POST STREET PARTNERS LLC', '$150,000-350,000', 'minimum loan'),
#  ('1001 3RD ST LLC', '$150,000-350,000', 'minimum loan'),
#  ('100S SEAFOOD BUFFET INC.', '$150,000-350,000', 'minimum loan'),
#  ('101 BUILDERS INC', '$350,000-1 million', 'small loan'),
#  ('101 PHOENIX INC', '$150,000-350,000', 'minimum loan'),
#  ('101 PIPE & CASING, INC.', '$150,000-350,000', 'minimum loan'),
#  ('101 STUDIOS, LLC', '$350,000-1 million', 'small loan'),
#  ('1016 LA CIENEGA, INC', '$150,000-350,000', 'minimum loan'),
#  ('1031 CROWDFUNDING, LLC', '$150,000-350,000', 'minimum loan'),
#  ('107 BROADWAY LOFTS AND SUITES, LLC', '$150,000-350,000', 'minimum loan'),
#  ('1099 PRO, INC.', '$350,000-1 million', 'small loan'),
#  ('10UP, INC.', '$2-5 million', 'above average loan'),
#  ('11 BRAVO INSURANCE SERVICES, INC', '$150,000-350,000', 'minimum loan'),
#  ('11 HEALTH AND TECHNOLOGIES, INC', '$350,000-1 million', 'small loan'),
#  ('11 VENTURA, LLC', '$150,000-350,000', 'minimum loan'),
#  ('110 F STREET LLC', '$350,000-1 million', 'small loan'),
#  ('110 SUNSHINE SMOOTHIES, INC.', '$350,000-1 million', 'small loan'),
#  ('1100 SOUTH ALVARADO STREET LLC', '$1-2 million', 'median loan'),
#  ('111 MINNA GALLERY, LLC', '$150,000-350,000', 'minimum loan'),
#  ('1114 GROUP LLC', '$150,000-350,000', 'minimum loan'),
#  ('1123 FOLSOM STREET LLC', '$150,000-350,000', 'minimum loan'),
#  ('11262 VENTURA LLC', '$150,000-350,000', 'minimum loan'),
#  ('1130 W. LA PALMA AVE, INC.', '$350,000-1 million', 'small loan'),
#  ('1131 HA INC', '$150,000-350,000', 'minimum loan'),
#  ('1135 N. LEISURE CT., INC.', '$350,000-1 million', 'small loan'),
#  ('11410 CANDLEWOOD INC', '$150,000-350,000', 'minimum loan'),
#  ('11480 SULPHUR MOUNTAIN ROAD, LLC', '$150,000-350,000', 'minimum loan'),
#  ('1150 HOWARD PARTNERS, L.P.', '$150,000-350,000', 'minimum loan'),
#  ('11500 COMFORT INC', '$150,000-350,000', 'minimum loan'),
#  ('1180 RAYMOND URBAN RENEWAL LLC', '$150,000-350,000', 'minimum loan'),
#  ('11TH ST WORKSHOP LA INC', '$350,000-1 million', 'small loan'),
#  ('12 CROWNS, INC.', '$150,000-350,000', 'minimum loan'),
#  ('12 SOUTH LLC', '$150,000-350,000', 'minimum loan'),
#  ('12 VENTURES, LLC', '$350,000-1 million', 'small loan'),
#  ('12072 TRASK INC.', '$1-2 million', 'median loan'),
#  ('120VC', '$150,000-350,000', 'minimum loan'),
#  ('12232 CHAPMAN AVE, INC.', '$1-2 million', 'median loan'),
#  ('1224 COTTONWOOD ASSOCIATES', '$150,000-350,000', 'minimum loan'),
#  ('1228 THIRTY SIXTH AVENUE LLC', '$150,000-350,000', 'minimum loan'),
#  ('123 BROADWAY PARTNERS LLC', '$150,000-350,000', 'minimum loan'),
#  ('123 MOVING AND STORAGE LLC', '$350,000-1 million', 'small loan'),
#  ('1234 M DIVISION STREET, INC.', '$150,000-350,000', 'minimum loan'),
#  ('123PCB CORPORATION DBA NETWORK PCB', '$150,000-350,000', 'minimum loan'),
#  ('124 GRAND HOLDINGS, INC', '$350,000-1 million', 'small loan'),
#  ('12TH WONDER LLC', '$150,000-350,000', 'minimum loan'),
#  ('12TWENTY, INC.', '$150,000-350,000', 'minimum loan'),
#  ('130 GRAND HOLDINGS INC', '$350,000-1 million', 'small loan'),
#  ('1300 BATTERY, INC.', '$350,000-1 million', 'small loan'),
#  ('13000 VICTORY BOULEVARD, LLC', '$350,000-1 million', 'small loan'),
#  ('13050SUSHI LLC', '$150,000-350,000', 'minimum loan'),
#  ('1318 FLOWER STREET, LLC', '$150,000-350,000', 'minimum loan'),
#  ('13822 SOUTH 46TH PLACE PROPCO, LLC', '$150,000-350,000', 'minimum loan'),
#  ('1394 TMN, INC.', '$150,000-350,000', 'minimum loan'),
#  ('140 CATTLE CO., INC.', '$150,000-350,000', 'minimum loan'),
#  ('140 MASON LLC', '$150,000-350,000', 'minimum loan'),
#  ('1400 RAILROAD AVENUE LTD', '$150,000-350,000', 'minimum loan'),
#  ('1400 WEST BRANCH LLC', '$150,000-350,000', 'minimum loan'),
#  ('143 S. LA BREA, INC', '$150,000-350,000', 'minimum loan'),
#  ('1440 OPCO, LLC', '$1-2 million', 'median loan'),
#  ('1450 NORTH FAIR OAKS LLC', '$350,000-1 million', 'small loan'),
#  ('1460 CAPITAL CORPORATION', '$350,000-1 million', 'small loan'),
#  ('1495 CAMERON AVE LLC', '$350,000-1 million', 'small loan'),
#  ('14FEET', '$150,000-350,000', 'minimum loan'),
#  ('14TH ROUND INC.', '$350,000-1 million', 'small loan'),
#  ('15 MAIN LLC', '$150,000-350,000', 'minimum loan'),
#  ('15 SECONDS OF FAME, INC.', '$350,000-1 million', 'small loan'),
#  ('15/40 PRODUCTIONS, LTD.', '$350,000-1 million', 'small loan'),
#  ('150 HEGENBERGER CAPITAL LLC', '$350,000-1 million', 'small loan'),
#  ('1500 MAJESTIC, LLC', '$150,000-350,000', 'minimum loan'),
#  ('1501 SOLANO AVENUE LLC', '$150,000-350,000', 'minimum loan'),
#  ('151 PARTNERS LLC', '$350,000-1 million', 'small loan'),
#  ('1512 W MISSION BLVD LLC', '$150,000-350,000', 'minimum loan'),
#  ('1544 CAHUENGA LLC', '$150,000-350,000', 'minimum loan'),
#  ('1562 CAHUENGA BLV BAR LLC', '$350,000-1 million', 'small loan'),
#  ('1570 FAIR OAKS LLC', '$350,000-1 million', 'small loan'),
#  ('1576 MISSION DRIVE, LLC', '$350,000-1 million', 'small loan'),
#  ('15TH & L INVESTORS, LLC', '$350,000-1 million', 'small loan'),
#  ('15TH DISTRICT AGRICULTURAL ASSOCIATION', '$350,000-1 million', 'small loan'),
#  ('16 MILES, INC.', '$150,000-350,000', 'minimum loan'),
#  ('1601 CAHUENGA NIGHTCLUB LLC', '$150,000-350,000', 'minimum loan'),
#  ('1611 EL CENTRO HOSPITALITY LLC', '$150,000-350,000', 'minimum loan'),
#  ('1615 CAHUENGA LLC', '$350,000-1 million', 'small loan'),
#  ('1616 AKB LP', '$150,000-350,000', 'minimum loan'),
#  ('1642 LAS PALMAS, LLC', '$150,000-350,000', 'minimum loan'),
#  ('16500 SIXTEEN FIVE HUNDRED', '$2-5 million', 'above average loan'),
#  ('16782 VON KARMAN AVE', '$1-2 million', 'median loan'),
#  ('16TH DISTRICT AGRICULTURAL ASSOCIATION', '$350,000-1 million', 'small loan'),
#  ('16TH STREET AUTO BODY', '$150,000-350,000', 'minimum loan'),
#  ('17 NORTH SAN PEDRO STREET PARTNERS LLC', '$350,000-1 million', 'small loan'),
#  ('1736 FAMILY CRISIS CENTER', '$1-2 million', 'median loan'),
#  ('1748 EL CAMINO REAL INC', '$150,000-350,000', 'minimum loan'),
#  ('18 ANIMAL GROUP, INC. DBA DBA PET VET AN IMAL HOSPITAL', '$150,000-350,000', 'minimum loan'),
#  ('18 BEDFORD AVE., LLC', '$350,000-1 million', 'small loan'),
#  ('18 BIRDIES LLC', '$350,000-1 million', 'small loan'),
#  ('18 HUNDRED INC', '$150,000-350,000', 'minimum loan'),
#  ('180 SNACKS, INC.', '$150,000-350,000', 'minimum loan'),
#  ('1810 DOWNTOWN RESTAURANT CORP', '$150,000-350,000', 'minimum loan'),
#  ('1835 COLUMBIA STREET, LP', '$350,000-1 million', 'small loan'),
#  ('1835 GGK TEAM INC', '$350,000-1 million', 'small loan'),
#  ('18421 VON KARMAN AVE, LLC', '$350,000-1 million', 'small loan'),
#  ('1850 HARBOR LLC', '$350,000-1 million', 'small loan'),
#  ('1850 INDUSTRIES, INC', '$150,000-350,000', 'minimum loan'),
#  ('1859, INC.', '$150,000-350,000', 'minimum loan'),
#  ('1865 CRAFT HOUSE & KITCHEN LLC', '$150,000-350,000', 'minimum loan'),
#  ('1865 MONTEREY ST INVESTORS LP', '$150,000-350,000', 'minimum loan'),
#  ('18800 MACARTHUR HMEJ', '$1-2 million', 'median loan'),
#  ('1895 FILMS', '$150,000-350,000', 'minimum loan'),
#  ('1899 RAYMOND LLC', '$1-2 million', 'median loan'),
#  ('18TH STREET COMMISSARY INC.', '$150,000-350,000', 'minimum loan'),
#  ('1948 MANAGEMENT GROUP, LLC', '$150,000-350,000', 'minimum loan'),
#  ('1951 COFFEE COMPANY', '$150,000-350,000', 'minimum loan'),
#  ('1953 CONSTRUCTION INC.', '$150,000-350,000', 'minimum loan'),
#  ('1978 ENTERPRISES', '$150,000-350,000', 'minimum loan'),
#  ('1984 INC', '$150,000-350,000', 'minimum loan'),
#  ('19SIX ARCHITECTS', '$350,000-1 million', 'small loan'),
#  ('19TH DISTRICT AGRICULTURAL ASSOCIATION', '$150,000-350,000', 'minimum loan'),
#  ('1MORE USA INC.', '$150,000-350,000', 'minimum loan'),
#  ('1R TOURING, INC', '$150,000-350,000', 'minimum loan'),
#  ('1ST AVENUE CAPITAL HOLDING LLC', '$150,000-350,000', 'minimum loan'),
#  ('1ST CHOICE FUMIGATION INC.', '$150,000-350,000', 'minimum loan'),
#  ('1ST CHOICE HOME HEALTH CARE & HOSPICE, INC', '$350,000-1 million', 'small loan'),
#  ('1ST CHOICE NANNY SERVICE LLC', '$150,000-350,000', 'minimum loan'),
#  ('1ST CLASS LAUNDRY', '$1-2 million', 'median loan'),
#  ('1ST COMMERCIAL REALTY GROUP, INC.', '$350,000-1 million', 'small loan'),
#  ('1ST LIGHT ENERGY INC', '$1-2 million', 'median loan'),
#  ('1ST LIGHT SALES CORP.', '$350,000-1 million', 'small loan'),
#  ('1ST NATIONWIDE MORTGAGE CORPORATION', '$150,000-350,000', 'minimum loan'),
#  ('1ST QUALITY PRODUCE', '$350,000-1 million', 'small loan'),
#  ('1ST RELIANT HOME LOANS INC', '$350,000-1 million', 'small loan'),
#  ('1ST STAGE PROPERTY TRANSFORMATION', '$150,000-350,000', 'minimum loan'),
#  ('1ST STEP APPLIED BEHAVIOR ANALYSTS', '$150,000-350,000', 'minimum loan'),
#  ('1ST STREET PAINTING', '$150,000-350,000', 'minimum loan'),
#  ('1STELLAR HEALTH, LLC', '$350,000-1 million', 'small loan'),
#  ('1TWENTYFOUR, INC.', '$150,000-350,000', 'minimum loan'),
#  ('1WININFALL LLC', '$150,000-350,000', 'minimum loan'),
#  ('2 BY C LLC', '$150,000-350,000', 'minimum loan'),
#  ('2 C RESTAURANTS, INC.', '$350,000-1 million', 'small loan'),
#  ('2 EVIL GENIUSES', '$350,000-1 million', 'small loan'),
#  ('2 EVIL GENIUSES', '$350,000-1 million', 'small loan'),
#  ('2 KINGS GAMING, INC', '$150,000-350,000', 'minimum loan'),
#  ('2 OAKS CORNER LODGING, LLC', '$150,000-350,000', 'minimum loan'),
#  ('2 PERCENT CHOP BARBERSHOP', '$150,000-350,000', 'minimum loan'),
#  ('2.0 REALTY PARTNERS, LLC DBA A STREET PARTNERS', '$350,000-1 million', 'small loan'),
#  ('2.7 AUGUST APPAREL, INC.', '$350,000-1 million', 'small loan'),
#  ('20-20 BUILDERS', '$150,000-350,000', 'minimum loan'),
#  ('20-20 GOURMET INC', '$150,000-350,000', 'minimum loan'),
#  ('20-2714097', '$150,000-350,000', 'minimum loan'),
#  ('20/20 ADMINISTRATIVE SERVICES, INC.', '$350,000-1 million', 'small loan'),
#  ('20/20 VISION ASSOCIATES OPTOMETRY, INC.', '$150,000-350,000', 'minimum loan'),
#  ('200 LIGHTHOUSE, LLC', '$350,000-1 million', 'small loan'),
#  ('2000 BLG, LLC', '$150,000-350,000', 'minimum loan'),
#  ('2000 E 7TH ST. LLC', '$350,000-1 million', 'small loan'),
#  ('200222222', '$150,000-350,000', 'minimum loan'),
#  ('2003 NATOMAS INN & SUITES LP', '$150,000-350,000', 'minimum loan'),
#  ('2004 CAPITOL INVESTMENTS', '$150,000-350,000', 'minimum loan'),
#  ('2010 OFFICE FURNITURE, INC.', '$150,000-350,000', 'minimum loan'),
#  ('2014 MI SOOK CHAI IRREVOCABLE TRUST', '$350,000-1 million', 'small loan'),
#  ('2014 SUPER DUPER, LLC', '$350,000-1 million', 'small loan'),
#  ('2020 MOBILE CORP', '$1-2 million', 'median loan'),
#  ('2021 PHYSICAL THERAPY GROUP, INC.', '$150,000-350,000', 'minimum loan'),
#  ('2030 UNION STREET LLC', '$350,000-1 million', 'small loan'),
#  ('2036 LOMBARD STREET, LLC', '$150,000-350,000', 'minimum loan'),
#  ('2040 SERVICES', '$150,000-350,000', 'minimum loan'),
#  ('205 KENTUCKY STREET LLC', '$150,000-350,000', 'minimum loan'),
#  ('209 TRUCKS LLC', '$150,000-350,000', 'minimum loan'),
#  ('20TH CENTURY AIR, INC.', '$150,000-350,000', 'minimum loan'),
#  ('21 OCEANFRONT RESTAURANT, INC', '$150,000-350,000', 'minimum loan'),
#  ('21 STAFF LLC', '$350,000-1 million', 'small loan'),
#  ('21-A DISTRICT AGRICULTURAL ASSOCIATION', '$150,000-350,000', 'minimum loan'),
#  ('214 TECHNOLOGIES INC', '$150,000-350,000', 'minimum loan'),
#  ('2191 S HARBOR, LLC', '$150,000-350,000', 'minimum loan'),
#  ('21ST AMENDMENT GROUP, LLC', '$150,000-350,000', 'minimum loan'),
#  ('21ST CENTURY HOME HEALTH SERVICES, INC.', '$350,000-1 million', 'small loan'),
#  ('21ST CENTURY HOME IMPROVEMENT PAINTING &', '$150,000-350,000', 'minimum loan'),
#  ('21ST CENTURY PERSONNEL, LLC', '$2-5 million', 'above average loan'),
#  ('21ST CENTURY STAFFING LLC', '$150,000-350,000', 'minimum loan'),
#  ('21ST DISTRICT AGRICULTURAL ASSOCIATION, THE BIG FRESNO FAIR', '$350,000-1 million', 'small loan'),
#  ('21TECH, LLC', '$1-2 million', 'median loan'),
#  ('22 CONSULTING LLC', '$350,000-1 million', 'small loan'),
#  ('220 GROUP LLC', '$350,000-1 million', 'small loan'),
#  ('220 LABORATORIES, INC.', '$5-10 million', 'maximum loan'),
#  ('2200 ONTARIO LLC', '$150,000-350,000', 'minimum loan'),
#  ('2210 SANTA ANA OPCO LLC', '$1-2 million', 'median loan'),
#  ('22125 ROSCOE CORPORATION', '$1-2 million', 'median loan'),
#  ('2219 HONOLULU AVENUE, INC.', '$150,000-350,000', 'minimum loan'),
#  ('2253 APPAREL, INC.', '$1-2 million', 'median loan'),
#  ('22ND DISTRICT AGRICULTURAL ASSOCIATION', '$2-5 million', 'above average loan'),
#  ('22ND STREET LANDING, LTD., A CALIFORNIA', '$350,000-1 million', 'small loan'),
#  ('23 BOTTLES OF BEER, LLC', '$2-5 million', 'above average loan'),
#  ('2301 SM LP', '$150,000-350,000', 'minimum loan'),
#  ('2301 THIRD AVENUE LP', '$350,000-1 million', 'small loan'),
#  ('2301 WB BUILDING LLC.', '$150,000-350,000', 'minimum loan'),
#  ('23240 HIGHWAY 1 LLC', '$350,000-1 million', 'small loan'),
#  ('2355 TELEGRAPH, LLC', '$150,000-350,000', 'minimum loan'),
#  ('2363 FOOTHILL LLC', '$350,000-1 million', 'small loan'),
#  ('23801 NEWHALL AVENUE LLC', '$350,000-1 million', 'small loan'),
#  ('24 CARROTS SPECIAL EVENTS, INC.', '$350,000-1 million', 'small loan'),
#  ('24 CARROTS, LLC', '$1-2 million', 'median loan'),
#  ('24 HOUR CAREGIVERS, INC.', '$150,000-350,000', 'minimum loan'),
#  ('24 HOURTEK INC', '$350,000-1 million', 'small loan'),
#  ('24-7 HIGHER STANDARD CORPORATION', '$150,000-350,000', 'minimum loan'),
#  ('24-7 STAT CARE AGENCY INC', '$350,000-1 million', 'small loan'),
#  ('24-7 UK SOCCER ACADEMY', '$350,000-1 million', 'small loan'),
#  ('24-HOUR MEDICAL STAFFING SERVICES, LLC', '$1-2 million', 'median loan'),
#  ('24-HR EXPRESS SERVICES, INC.', '$350,000-1 million', 'small loan'),
#  ('24-SEVEN HOME HEALTH INC.', '$350,000-1 million', 'small loan'),
#  ('24/7 FAMILY HOMECARE AND VETERANS SERVICES', '$150,000-350,000', 'minimum loan'),
#  ('24/7 HOSPICE', '$150,000-350,000', 'minimum loan'),
#  ('24/7 PETVETS', '$150,000-350,000', 'minimum loan'),
#  ('24/7 QUALITY INFUSION AND HOME HEALTH', '$150,000-350,000', 'minimum loan'),
#  ('24/7 ROOTER AND PLUMBING SERVICES INC.', '$150,000-350,000', 'minimum loan'),
#  ('2400 LOMBARD LLC', '$150,000-350,000', 'minimum loan'),
#  ('2401 LAMAR (DALLAS) ESONG LLC', '$350,000-1 million', 'small loan'),
#  ('2401 SEAL BEACH LLC DBA HAMPTON INN AND SUITES IN SEAL BEACH', '$150,000-350,000', 'minimum loan'),
#  ('241 MAIN, LLC', '$150,000-350,000', 'minimum loan'),
#  ('2435 MAIN INC', '$150,000-350,000', 'minimum loan'),
#  ('2448 EAST 25TH STREET LLC', '$350,000-1 million', 'small loan'),
#  ('2450 COLORADO BLVD LLC', '$150,000-350,000', 'minimum loan'),
#  ('2454 WILSHIRE RESTAURANT, LLC', '$350,000-1 million', 'small loan'),
#  ('247 DELIVERS, INC.', '$150,000-350,000', 'minimum loan'),
#  ('24HRC', '$350,000-1 million', 'small loan'),
#  ('24K VENTURES, INC.', '$150,000-350,000', 'minimum loan'),
#  ('250 FOURTH DEVELOPMENT, L.P.', '$2-5 million', 'above average loan'),
#  ('2585 ORO DAM LLC', '$150,000-350,000', 'minimum loan'),
#  ('26 BEACH RESTAURANT', '$150,000-350,000', 'minimum loan'),
#  ('26 BRIX, LLC', '$350,000-1 million', 'small loan'),
#  ('26 CALIFORNIA BAZAR WHOLESALE', '$150,000-350,000', 'minimum loan'),
#  ('26 INTERNATIONAL, INC.', '$150,000-350,000', 'minimum loan'),
#  ('2600HZ INC', '$350,000-1 million', 'small loan'),
#  ('2611 CONTRA COSTA CA LLC', '$150,000-350,000', 'minimum loan'),
#  ('26306 DIAMOND PLACE, LLC, EPC SALAZAR CONST. CO. & SKY CITY CO. INC., OC', '$350,000-1 million', 'small loan'),
#  ('2723 PARTNERS LP', '$350,000-1 million', 'small loan'),
#  ('2725 - 2727 - 2729, INC. DBA SEAFOOD CENTRAL', '$150,000-350,000', 'minimum loan'),
#  ('280 CAPMARKETS LLC', '$1-2 million', 'median loan'),
#  ('280 GROUP LLC', '$350,000-1 million', 'small loan'),
#  ('28863 ROADSIDE DRIVE, LLC', '$150,000-350,000', 'minimum loan'),
#  ('29 POTATOES LLC', '$150,000-350,000', 'minimum loan'),
#  ('2961 STATE ST INC', '$150,000-350,000', 'minimum loan'),
#  ('2B LIVING', '$350,000-1 million', 'small loan'),
#  ('2GO PRODUCTS, LLC', '$150,000-350,000', 'minimum loan'),
#  ('2H CONSTRUCTION INC', '$1-2 million', 'median loan'),
#  ('2KDIRECT, INC.', '$350,000-1 million', 'small loan'),
#  ('2L PLUS', '$150,000-350,000', 'minimum loan'),
#  ('2MANGAS INCORPORATED', '$150,000-350,000', 'minimum loan'),
#  ('2ND NATURE FILMS LLC', '$150,000-350,000', 'minimum loan'),
#  ('2ND TRY LLC', '$150,000-350,000', 'minimum loan'),
#  ('2NDNATURE SOFTWARE INC', '$150,000-350,000', 'minimum loan'),
#  ('2S2G CONTRACTING, INC.', '$150,000-350,000', 'minimum loan'),
#  ('2W INTERNATIONAL', '$150,000-350,000', 'minimum loan'),
#  ('3 AMIGOS FRESH MEXICAN GRILL', '$150,000-350,000', 'minimum loan'),
#  ('3 AMIGOS PIZZA INC', '$350,000-1 million', 'small loan'),
#  ('3 BADGE BEVERAGE CORPORATION', '$350,000-1 million', 'small loan'),
#  ('3 BLIND MICE WINDOW COVERINGS, INC', '$150,000-350,000', 'minimum loan'),
#  ('3 BMG, LLC', '$150,000-350,000', 'minimum loan'),
#  ('3 BRAND CATTLE CO.', '$150,000-350,000', 'minimum loan'),
#  ('3 BRIDGE NETWORKS LLC', '$350,000-1 million', 'small loan'),
#  ('3 BROTHERS CONSTRUCTION AND RENTAL INC.', '$350,000-1 million', 'small loan'),
#  ('3 GENERACIONES LLC', '$1-2 million', 'median loan'),
#  ('3 K TECHNOLOGIES LLC', '$350,000-1 million', 'small loan'),
#  ('3 MACHADOS DAIRY, INC', '$150,000-350,000', 'minimum loan'),
#  ('3 PHASES RENEWABLES INC', '$150,000-350,000', 'minimum loan'),
#  ('3 POINT DISTRIBUTION LLC', '$150,000-350,000', 'minimum loan'),
#  ('3 S NETWORK, INC.', '$350,000-1 million', 'small loan'),
#  ('3 S SIGN SERVICES, INC.', '$150,000-350,000', 'minimum loan'),
#  ('3 SIDES CLEAR', '$150,000-350,000', 'minimum loan'),
#  ('3 SUNS, LLC', '$150,000-350,000', 'minimum loan'),
#  ('3 VENEZIE, LP', '$350,000-1 million', 'small loan'),
#  ('3 WAY THRIFT STORE INC.', '$350,000-1 million', 'small loan'),
#  ('3 Y POWER TECHNOLOGY INC', '$150,000-350,000', 'minimum loan'),
#  ('3-D / FASTENERS PLUS, INC.', '$150,000-350,000', 'minimum loan'),
#  ('3-D ENGINEERING CORP', '$150,000-350,000', 'minimum loan'),
#  ('3-D ENTERPRISES, INCORPORATED', '$350,000-1 million', 'small loan'),
#  ('3-DOWNTOWN BARS INC', '$150,000-350,000', 'minimum loan')]

# %% [markdown]
# # Exploratory Query - 2
#
# __Business Request:__ _Your manager would like for you to retrieve the number of businesses that requested a given loan amount per size._
#
# __(Follow Up) Question:__ _How many businesses requested each specified loan range? What size of loan currently appears to be the most requested?_
#
# __Business Justification:__ _The team wants to know which loan was most highly requested versus the loan amount least requested amongst current applications._
#
# SQL Features Used: _COUNT, CASE_

# %%
# %%sql
# SELECT
# 	COUNT(
# 		CASE
# 	  		WHEN loan_amount = '$150,000-350,000' THEN 'minimum loan'
# 	  	END) AS minimum_loan_count,
#     COUNT(
# 		CASE
# 	  		WHEN loan_amount = '$350,000-1 million' THEN 'small loan'
# 	  	END) AS small_loan_count,
#     COUNT(
# 		CASE
# 	  		WHEN loan_amount = '$1-2 million' THEN 'median loan'
# 	  	END) AS median_loan_count,
#     COUNT(
# 		CASE
# 	  		WHEN loan_amount = '$2-5 million' THEN 'above average loan'
# 	  	END) AS above_average_loan_count,
#     COUNT(
# 		CASE
# 	  		WHEN loan_amount = '$5-10 million' THEN 'maximum loan'
# 	  	END) AS maximum_loan_count,
#     COUNT(*) AS total_loan_applications
# FROM CaliforniaLoanApplication;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 1 rows affected.
# [(171, 99, 22, 6, 2, 300)]

# %% [markdown]
# # Exploratory Query - 3
#
# __Business Request:__ _The team who is working on the development and execution of JP Morgan's initiative wants to verify information. Identify missing data within the applications of U.S. businesses who applied for a grant._
#
# __Question:__ _What businesses have a null or missing value within the industry column and how many?_
#
# __Business Justification:__ _The team wants to make sure the quality of their data is correct and presented efficiently when using it for presentation or documentation purposes such as within certain statements (for publication purposes, financial details, or otherwise)._
#
# SQL Features Used: _COUNT, GROUP BY, JOIN, SUBQUERY, ORDER BY_

# %%
# %%sql
# SELECT
#     industry,
#     COUNT(industry) AS Number_of_Companies
# FROM StateWideGrantApplication
# GROUP BY industry;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 9 rows affected.
# [('Repair Services', 56),
#  ('', 11),
#  ('Health, Beauty, and Fitness', 63),
#  ('Retail', 36),
#  ('Food Services', 46),
#  ('Sports and Recreation', 46),
#  ('Maintenance', 42),
#  ('Advertising', 48),
#  ('Technology', 52)]

# %%
# %%sql
# SELECT
#     swga.industry,
#     COUNT(swga.industry) AS number_of_companies
# FROM StateWideGrantApplication swga
# JOIN
#     (
#         SELECT *
#         FROM StateWideGrantApplication
#         WHERE industry NOT IN ('Technology','Repair Services','Health, Beauty, and Fitness','Retail','Food Services','Maintenance','Sports and Recreation','Advertising')
#     ) AS Missing_Industry
#     ON swga.grant_application_id = Missing_Industry.grant_application_id
# GROUP BY industry
# ORDER BY number_of_companies DESC;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 1 rows affected.
# [('', 11)]

# %% [markdown]
# __FOLLOW UP REQUEST FROM YOUR MANAGER:__
#
# Follow up with businesses who had a null value, find their respective industry, and document it:
#
# SQL Features Used: _COUNT, GROUP BY_

# %%
# %%sql
# SELECT
#     industry,
#     COUNT(industry) AS number_of_businesses
# FROM StateWideGrantApplication
# GROUP BY industry;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 8 rows affected.
# [('Food Services', 71),
#  ('Retail', 43),
#  ('Advertising', 45),
#  ('Sports and Recreation', 51),
#  ('Technology', 61),
#  ('Maintenance', 51),
#  ('Repair Services', 43),
#  ('Health, Beauty, and Fitness', 35)]

# %% [markdown]
# # Exploratory Query - 4
# __Business Request:__ _Your manager would like for you to return a list in alphabetical order providing the names of entrepreneurs who applied for either a grant or a loan. Provide their contact information and primary residency so that they may receive announcements regarding additional opportunities they may qualify for. Distinguish the type of aid they applied for and the ethnic background they identify with._
#
# __Question:__ _What are the names of all the current applicants, their phone number, email address, state, ethnicity, and what type of aid applicant are they?_
#
# __Business Justification:__ _The team wants to have this data on file for future reference and would like for it to update as interested entrepreneurs continue to apply. This helps with efficiency by maintaining an updated database and being able to communicate with people on the interest list._
#
# SQL Features Used: _VIEW, CONCAT, SubType, JOIN, UNION, ORDER BY_

# %%
# %%sql
# CREATE OR REPLACE VIEW Applicant_Information AS
#     SELECT
#         CONCAT(ola.first_name,' ', ola.last_name) AS Entrepreneur,
#         ei.ethnic_group AS Ethnicity,
#         phone_number,
#         email,
#         state,
#         'Loan Applicant' AS Aid_Form_Requested
#     FROM Owners_LoanApplicants ola
#     JOIN EthnicIdentity ei
#         ON ola.ethnic_id = ei.ethnic_id
#     UNION
#     SELECT
#         CONCAT(oga.first_name,' ', oga.last_name),
#         ei.ethnic_group,
#         phone_number,
#         email,
#         state,
#         'Grant Applicant'
#     FROM Owners_GrantApplicants oga
#     JOIN EthnicIdentity ei
#         ON oga.ethnic_id = ei.ethnic_id
#     ORDER BY Entrepreneur;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM Applicant_Information;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 700 rows affected.
# [('Aaron Guy', 'Asian', '1-245-731-0798', 'sagittis.augue@euplacerat.co.uk', 'Nebraska', 'Grant Applicant'),
#  ('Aaron Salinas', 'Asian', '1-200-873-0410', 'Curae.Phasellus.ornare@gravidaPraesenteu.edu', 'Idaho', 'Grant Applicant'),
#  ('Aaron Wong', 'Black or African American', '1-752-864-5351', 'tincidunt.dui@adipiscingelit.co.uk', 'Arkansas', 'Loan Applicant'),
#  ('Abraham Baker', 'Native Hawaiian or Other Pacific Islander', '1-644-623-3342', 'facilisis@id.edu', 'Wyoming', 'Grant Applicant'),
#  ('Addison Holman', 'Native Hawaiian or Other Pacific Islander', '1-366-409-6989', 'Nam.porttitor.scelerisque@musProin.org', 'Pennsylvania', 'Loan Applicant'),
#  ('Adena Mcgowan', 'Middle Eastern', '1-472-758-2379', 'in.magna.Phasellus@posuerecubilia.ca', 'Alaska', 'Loan Applicant'),
#  ('Adena Ray', 'Black or African American', '1-872-990-6291', 'mattis.ornare@sempercursusInteger.com', 'Hawaii', 'Loan Applicant'),
#  ('Adria Cameron', 'Native Hawaiian or Other Pacific Islander', '1-262-877-6150', 'non.lobortis@Praesentinterdum.co.uk', 'Idaho', 'Loan Applicant'),
#  ('Adrian Alexander', 'Asian', '1-289-602-3420', 'non@pedesagittisaugue.edu', 'Arizona', 'Grant Applicant'),
#  ('Aidan Gaines', 'Asian', '1-694-622-8455', 'nunc.risus@ornareFuscemollis.ca', 'Washington', 'Loan Applicant'),
#  ('Aidan Park', 'Native Hawaiian or Other Pacific Islander', '1-564-232-7152', 'tincidunt.nibh.Phasellus@acturpis.org', 'Connecticut', 'Grant Applicant'),
#  ('Aileen Barr', 'Middle Eastern', '1-114-177-9308', 'eget.ipsum.Donec@Integereu.edu', 'Michigan', 'Loan Applicant'),
#  ('Akeem Jones', 'American Indian or Alaska Native', '1-114-714-1358', 'pede.blandit@arcuiaculis.ca', 'Tennessee', 'Grant Applicant'),
#  ('Aladdin Snider', 'Black or African American', '1-965-621-7369', 'erat@risusNulla.edu', 'Missouri', 'Grant Applicant'),
#  ('Alan Acosta', 'American Indian or Alaska Native', '1-281-210-1650', 'scelerisque.scelerisque@blanditmattisCras.edu', 'Wisconsin', 'Grant Applicant'),
#  ('Alan Powers', 'Black or African American', '1-138-741-2160', 'Maecenas.mi@ametorciUt.co.uk', 'Georgia', 'Grant Applicant'),
#  ('Alden Huff', 'Middle Eastern', '1-426-784-6933', 'erat.neque@orci.edu', 'Nevada', 'Loan Applicant'),
#  ('Alea Dawson', 'Native Hawaiian or Other Pacific Islander', '1-494-595-9566', 'placerat@et.co.uk', 'Wyoming', 'Grant Applicant'),
#  ('Alec Briggs', 'Middle Eastern', '1-652-470-1428', 'eros.non@eleifendnunc.net', 'Connecticut', 'Loan Applicant'),
#  ('Alexa Caldwell', 'Black or African American', '1-628-844-4687', 'odio@diamluctuslobortis.co.uk', 'Wyoming', 'Loan Applicant'),
#  ('Alexander Barker', 'Hispanic or Latinx', '1-161-648-2315', 'id@congueelit.net', 'Tennessee', 'Loan Applicant'),
#  ('Alexis Robbins', 'American Indian or Alaska Native', '1-251-632-5821', 'facilisis@Donec.ca', 'Ohio', 'Grant Applicant'),
#  ('Ali Hardy', 'Hispanic or Latinx', '1-348-728-4625', 'elementum@cursusNunc.co.uk', 'Tennessee', 'Grant Applicant'),
#  ('Alika Rodgers', 'Middle Eastern', '1-481-173-2402', 'dapibus@vulputatelacusCras.net', 'Nevada', 'Grant Applicant'),
#  ('Alisa Burch', 'Hispanic or Latinx', '1-477-433-6115', 'risus@et.co.uk', 'Illinois', 'Loan Applicant'),
#  ('Allegra Skinner', 'Black or African American', '1-860-494-4424', 'egestas.Duis@dictumplacerataugue.edu', 'Minnesota', 'Loan Applicant'),
#  ('Allegra Warner', 'Native Hawaiian or Other Pacific Islander', '1-656-959-0310', 'sed.pede.nec@purusaccumsan.edu', 'Delaware', 'Loan Applicant'),
#  ('Amal Adams', 'Native Hawaiian or Other Pacific Islander', '1-288-312-1637', 'Etiam@ametornarelectus.ca', 'Iowa', 'Grant Applicant'),
#  ('Amal Graham', 'Asian', '1-957-986-1455', 'non.bibendum.sed@Quisquenonummy.edu', 'Alabama', 'Grant Applicant'),
#  ('Amela Watts', 'Black or African American', '1-405-886-1176', 'lacus.pede.sagittis@urnasuscipitnonummy.com', 'Virginia', 'Grant Applicant'),
#  ('Amir Bruce', 'Hispanic or Latinx', '1-650-174-6940', 'massa.Integer@ultrices.org', 'Massachusetts', 'Grant Applicant'),
#  ('Amir Figueroa', 'Hispanic or Latinx', '1-881-989-3016', 'sem.consequat.nec@faucibus.co.uk', 'Mississippi', 'Grant Applicant'),
#  ('Amity Herman', 'American Indian or Alaska Native', '1-755-370-1908', 'Suspendisse.commodo@a.net', 'Mississippi', 'Loan Applicant'),
#  ('Amos Weaver', 'Hispanic or Latinx', '1-388-525-0734', 'Cras.pellentesque@musProinvel.net', 'Montana', 'Grant Applicant'),
#  ('Andrew Herrera', 'Middle Eastern', '1-121-533-2023', 'euismod@ante.net', 'Tennessee', 'Loan Applicant'),
#  ('Anthony Cooke', 'Hispanic or Latinx', '1-543-901-7977', 'sem.mollis.dui@auctor.edu', 'Kansas', 'Grant Applicant'),
#  ('Anthony Dennis', 'Middle Eastern', '1-418-894-8581', 'magnis@metussitamet.com', 'Maine', 'Grant Applicant'),
#  ('Aphrodite Foster', 'Middle Eastern', '1-463-150-8906', 'dui@nonummyFusce.org', 'California', 'Loan Applicant'),
#  ('Aquila Schmidt', 'Native Hawaiian or Other Pacific Islander', '1-421-788-7308', 'ligula.Nullam@Aliquamfringilla.co.uk', 'Missouri', 'Loan Applicant'),
#  ('Arden Finley', 'Hispanic or Latinx', '1-656-974-2482', 'enim@hendreritconsectetuercursus.org', 'Hawaii', 'Grant Applicant'),
#  ('Ariel Molina', 'Black or African American', '1-525-186-8255', 'ornare.egestas.ligula@faucibusidlibero.edu', 'Vermont', 'Grant Applicant'),
#  ('Armand Kim', 'Middle Eastern', '1-466-215-7580', 'Aliquam.fringilla.cursus@gravidanunc.co.uk', 'Montana', 'Grant Applicant'),
#  ('Arthur Allison', 'Native Hawaiian or Other Pacific Islander', '1-402-692-2976', 'amet.ornare.lectus@nequenon.ca', 'Texas', 'Grant Applicant'),
#  ('Ashely Moreno', 'Middle Eastern', '1-671-521-6894', 'amet.faucibus@vulputateduinec.com', 'Wyoming', 'Loan Applicant'),
#  ('Ashton Workman', 'Black or African American', '1-499-409-0571', 'erat.vel@utpellentesqueeget.net', 'Louisiana', 'Grant Applicant'),
#  ('Aspen Lynn', 'Black or African American', '1-893-502-0083', 'mus@convallis.org', 'Wisconsin', 'Grant Applicant'),
#  ('Aspen Medina', 'Middle Eastern', '1-376-751-6749', 'mauris.id.sapien@magna.net', 'Ohio', 'Loan Applicant'),
#  ('Aubrey Cash', 'Native Hawaiian or Other Pacific Islander', '1-346-101-8245', 'pulvinar.arcu@Sedid.com', 'Massachusetts', 'Grant Applicant'),
#  ('Aubrey Trujillo', 'Native Hawaiian or Other Pacific Islander', '1-189-460-0260', 'dui.Cum.sociis@amet.ca', 'Wisconsin', 'Loan Applicant'),
#  ('Audrey Riddle', 'Middle Eastern', '1-826-640-3790', 'magna@vitae.ca', 'Wisconsin', 'Loan Applicant'),
#  ('August Serrano', 'Black or African American', '1-814-911-2644', 'Duis.at@egestasFuscealiquet.net', 'Illinois', 'Grant Applicant'),
#  ('Aurelia Melton', 'Native Hawaiian or Other Pacific Islander', '1-981-641-7638', 'neque.Nullam@consequatdolor.co.uk', 'Kentucky', 'Loan Applicant'),
#  ('Aurora David', 'Asian', '1-281-522-6977', 'velit.egestas@sagittis.net', 'Delaware', 'Loan Applicant'),
#  ('Austin Roberson', 'Black or African American', '1-794-596-0459', 'magna.a@euerosNam.edu', 'Maryland', 'Grant Applicant'),
#  ('Autumn Mcbride', 'American Indian or Alaska Native', '1-622-397-6224', 'congue.In.scelerisque@ac.com', 'Indiana', 'Loan Applicant'),
#  ('Ava Oneal', 'Native Hawaiian or Other Pacific Islander', '1-841-981-4907', 'urna@Crassed.ca', 'Massachusetts', 'Grant Applicant'),
#  ('Ava Reeves', 'Native Hawaiian or Other Pacific Islander', '1-905-646-0842', 'quis.tristique.ac@Nullaeu.co.uk', 'Tennessee', 'Loan Applicant'),
#  ('Avram Whitley', 'American Indian or Alaska Native', '1-890-845-3373', 'Morbi.sit.amet@Nunccommodoauctor.co.uk', 'Georgia', 'Loan Applicant'),
#  ('Avye Gillespie', 'Native Hawaiian or Other Pacific Islander', '1-749-823-6948', 'lobortis.quam@hymenaeosMaurisut.edu', 'Massachusetts', 'Loan Applicant'),
#  ('Barclay Stout', 'Native Hawaiian or Other Pacific Islander', '1-768-807-2157', 'malesuada@suscipitnonummyFusce.edu', 'Florida', 'Grant Applicant'),
#  ('Barry Bruce', 'Hispanic or Latinx', '1-842-595-7046', 'Nulla@mattisornarelectus.org', 'Maryland', 'Grant Applicant'),
#  ('Basil Buchanan', 'Hispanic or Latinx', '1-455-342-3462', 'velit@diamluctus.com', 'Oregon', 'Loan Applicant'),
#  ('Basil Cline', 'Native Hawaiian or Other Pacific Islander', '1-340-492-5592', 'orci@idante.co.uk', 'Pennsylvania', 'Grant Applicant'),
#  ('Basil Huber', 'Hispanic or Latinx', '1-477-590-0639', 'sodales.elit@auctorquistristique.net', 'Vermont', 'Loan Applicant'),
#  ('Beatrice Delacruz', 'Black or African American', '1-407-876-6974', 'per@Morbisit.org', 'Nevada', 'Loan Applicant'),
#  ('Beatrice Ramsey', 'Middle Eastern', '1-818-435-5976', 'odio.auctor.vitae@Quisquefringillaeuismod.net', 'Idaho', 'Grant Applicant'),
#  ('Bell Lester', 'Black or African American', '1-634-562-4138', 'Phasellus.dolor.elit@pedeCumsociis.ca', 'Arizona', 'Loan Applicant'),
#  ('Benedict Long', 'Hispanic or Latinx', '1-548-605-7939', 'pede.Suspendisse.dui@lorem.co.uk', 'Louisiana', 'Loan Applicant'),
#  ('Benedict Sweeney', 'Hispanic or Latinx', '1-128-832-6223', 'imperdiet@quam.ca', 'Ohio', 'Grant Applicant'),
#  ('Benjamin Delgado', 'Black or African American', '1-165-841-6068', 'sit@senectusetnetus.edu', 'Missouri', 'Loan Applicant'),
#  ('Benjamin Rodriguez', 'Native Hawaiian or Other Pacific Islander', '1-391-765-0410', 'leo.elementum.sem@elit.com', 'Missouri', 'Grant Applicant'),
#  ('Berk Haley', 'Native Hawaiian or Other Pacific Islander', '1-927-565-6820', 'vel.faucibus@lectussit.com', 'Vermont', 'Grant Applicant'),
#  ('Bethany Floyd', 'Hispanic or Latinx', '1-433-244-1128', 'tristique@Duis.net', 'Michigan', 'Grant Applicant'),
#  ('Bethany Wallace', 'Middle Eastern', '1-864-622-6058', 'dolor.dolor@acfermentum.edu', 'Colorado', 'Grant Applicant'),
#  ('Beverly Burnett', 'Asian', '1-766-167-6726', 'egestas.a@pedeCrasvulputate.ca', 'Alabama', 'Loan Applicant'),
#  ('Beverly Ewing', 'Hispanic or Latinx', '1-487-933-3738', 'nec.malesuada@iaculislacuspede.org', 'Georgia', 'Loan Applicant'),
#  ('Bevis Roach', 'Asian', '1-126-257-4626', 'cursus.diam@elementum.edu', 'Washington', 'Loan Applicant'),
#  ('Bianca Russo', 'American Indian or Alaska Native', '1-809-210-7412', 'natoque.penatibus.et@Aliquam.edu', 'Virginia', 'Grant Applicant'),
#  ('Blaine Justice', 'Native Hawaiian or Other Pacific Islander', '1-232-131-7357', 'adipiscing@IncondimentumDonec.com', 'Virginia', 'Grant Applicant'),
#  ('Blaine Valenzuela', 'Native Hawaiian or Other Pacific Islander', '1-651-533-5971', 'Nulla.interdum@mollis.co.uk', 'Maryland', 'Loan Applicant'),
#  ('Blair Holden', 'Middle Eastern', '1-424-793-2987', 'felis.orci.adipiscing@laciniamattis.edu', 'Arizona', 'Grant Applicant'),
#  ('Blake Larsen', 'Middle Eastern', '1-537-169-0589', 'non.enim.Mauris@elit.ca', 'Florida', 'Grant Applicant'),
#  ('Blaze Case', 'Hispanic or Latinx', '1-520-417-8478', 'bibendum.sed.est@sem.org', 'Missouri', 'Loan Applicant'),
#  ('Blaze Dennis', 'Native Hawaiian or Other Pacific Islander', '1-821-520-0896', 'urna.convallis.erat@arcuiaculisenim.net', 'Delaware', 'Grant Applicant'),
#  ('Blaze Nunez', 'American Indian or Alaska Native', '1-191-719-3787', 'lobortis.ultrices.Vivamus@euelitNulla.co.uk', 'Utah', 'Loan Applicant'),
#  ('Blythe Cox', 'Middle Eastern', '1-488-378-9711', 'eu@dapibusquam.net', 'Maine', 'Grant Applicant'),
#  ('Boris Henry', 'American Indian or Alaska Native', '1-681-110-1353', 'Integer.eu@sodalesat.org', 'Oregon', 'Grant Applicant'),
#  ('Bradley Byers', 'Hispanic or Latinx', '1-600-250-1761', 'Praesent@turpis.net', 'Nebraska', 'Loan Applicant'),
#  ('Brady Albert', 'American Indian or Alaska Native', '1-726-936-5058', 'sit.amet.massa@montes.edu', 'Nevada', 'Grant Applicant'),
#  ('Brady Hurst', 'Native Hawaiian or Other Pacific Islander', '1-455-640-7644', 'Aliquam@utpellentesque.co.uk', 'Massachusetts', 'Loan Applicant'),
#  ('Branden Bradshaw', 'Native Hawaiian or Other Pacific Islander', '1-921-435-8125', 'vel@antelectus.co.uk', 'Michigan', 'Grant Applicant'),
#  ('Branden Carr', 'Native Hawaiian or Other Pacific Islander', '1-525-311-4942', 'ligula@Mauris.edu', 'Illinois', 'Grant Applicant'),
#  ('Brandon Byers', 'Middle Eastern', '1-552-247-3484', 'lobortis.augue@sitamet.co.uk', 'California', 'Loan Applicant'),
#  ('Bree Fleming', 'Asian', '1-207-193-8128', 'fermentum@feugiatnonlobortis.net', 'Kentucky', 'Loan Applicant'),
#  ('Brendan Pratt', 'Black or African American', '1-482-926-6190', 'Quisque@luctusfelis.ca', 'Tennessee', 'Grant Applicant'),
#  ('Brennan Juarez', 'Hispanic or Latinx', '1-453-708-2180', 'metus.Vivamus@semutcursus.net', 'Hawaii', 'Loan Applicant'),
#  ('Brian Smith', 'Native Hawaiian or Other Pacific Islander', '1-391-559-6345', 'nec.orci@bibendumsedest.net', 'Oklahoma', 'Grant Applicant'),
#  ('Brianna Pennington', 'Asian', '1-978-638-9950', 'auctor.vitae@primisin.edu', 'Wyoming', 'Grant Applicant'),
#  ('Brianna Rios', 'American Indian or Alaska Native', '1-927-951-4625', 'massa@gravida.com', 'Nebraska', 'Loan Applicant'),
#  ('Briar Cohen', 'Hispanic or Latinx', '1-206-513-1971', 'erat.Sed@lectus.ca', 'Virginia', 'Loan Applicant'),
#  ('Brock Bowers', 'Middle Eastern', '1-397-563-4691', 'eget.lacus@Nullamlobortis.com', 'Alabama', 'Grant Applicant'),
#  ('Bruno Charles', 'Hispanic or Latinx', '1-938-612-4985', 'vitae.sodales.nisi@ullamcorper.co.uk', 'Connecticut', 'Grant Applicant'),
#  ('Bryar Greene', 'Native Hawaiian or Other Pacific Islander', '1-397-157-6006', 'tortor@ipsumnuncid.com', 'Nebraska', 'Grant Applicant'),
#  ('Brynne Lawson', 'American Indian or Alaska Native', '1-985-125-3896', 'a.odio@orciluctus.edu', 'Arkansas', 'Grant Applicant'),
#  ('Buckminster Flynn', 'Black or African American', '1-744-183-8037', 'Nulla.eget@nonarcu.net', 'Oklahoma', 'Loan Applicant'),
#  ('Buffy Owen', 'Hispanic or Latinx', '1-311-339-9469', 'Quisque.nonummy.ipsum@auctornon.net', 'Pennsylvania', 'Grant Applicant'),
#  ('Burke Foster', 'American Indian or Alaska Native', '1-806-883-5671', 'tortor.Nunc.commodo@elitpharetraut.net', 'Arkansas', 'Grant Applicant'),
#  ('Burton Francis', 'Black or African American', '1-521-416-4054', 'erat@adlitora.ca', 'Arizona', 'Loan Applicant'),
#  ('Cade Madden', 'Black or African American', '1-879-993-7839', 'feugiat.tellus@tinciduntvehicularisus.net', 'Vermont', 'Loan Applicant'),
#  ('Cailin Becker', 'Hispanic or Latinx', '1-632-268-3495', 'leo.Cras.vehicula@ultricesVivamusrhoncus.net', 'Illinois', 'Loan Applicant'),
#  ('Caldwell Edwards', 'Hispanic or Latinx', '1-500-753-3424', 'dis.parturient@elementum.co.uk', 'Massachusetts', 'Loan Applicant'),
#  ('Caldwell Murray', 'Asian', '1-108-580-5208', 'risus@dictum.edu', 'Massachusetts', 'Grant Applicant'),
#  ('Caleb Foster', 'Hispanic or Latinx', '1-344-662-6644', 'vitae.aliquet.nec@euodio.org', 'Idaho', 'Loan Applicant'),
#  ('Caleb Fuentes', 'Hispanic or Latinx', '1-397-217-1010', 'a.ultricies.adipiscing@loremvitaeodio.com', 'Alaska', 'Grant Applicant'),
#  ('Caleb Sutton', 'Middle Eastern', '1-835-146-6969', 'habitant.morbi.tristique@auctorullamcorper.edu', 'Indiana', 'Loan Applicant'),
#  ('Calista Thomas', 'Native Hawaiian or Other Pacific Islander', '1-856-150-9912', 'bibendum.ullamcorper.Duis@elementum.com', 'Iowa', 'Loan Applicant'),
#  ('Callum Hendrix', 'Native Hawaiian or Other Pacific Islander', '1-711-323-0279', 'molestie@lectussit.co.uk', 'Hawaii', 'Loan Applicant'),
#  ('Camden Larson', 'Asian', '1-983-369-7012', 'quam.vel@ut.org', 'Maryland', 'Loan Applicant'),
#  ('Cameran Foreman', 'Hispanic or Latinx', '1-707-310-8235', 'ac.tellus.Suspendisse@leoCras.ca', 'Indiana', 'Loan Applicant'),
#  ('Cameron Bright', 'Asian', '1-524-618-0856', 'Aliquam.ornare.libero@Duissit.org', 'Pennsylvania', 'Grant Applicant'),
#  ('Cameron Good', 'Black or African American', '1-434-507-2453', 'neque.vitae@Innec.net', 'Massachusetts', 'Loan Applicant'),
#  ('Cameron Nichols', 'Native Hawaiian or Other Pacific Islander', '1-153-157-9340', 'urna.Ut.tincidunt@arcuVestibulum.co.uk', 'Vermont', 'Grant Applicant'),
#  ('Cameron Richmond', 'Hispanic or Latinx', '1-508-621-9148', 'consectetuer.rhoncus.Nullam@fringillacursuspurus.co.uk', 'Indiana', 'Loan Applicant'),
#  ('Camilla Flowers', 'Middle Eastern', '1-586-688-3611', 'magna.Phasellus@consequatlectussit.edu', 'Nevada', 'Grant Applicant'),
#  ('Carol Dotson', 'Asian', '1-242-475-6301', 'tincidunt.pede.ac@Suspendisse.ca', 'Idaho', 'Loan Applicant'),
#  ('Carol Rojas', 'Native Hawaiian or Other Pacific Islander', '1-741-705-9273', 'semper@in.com', 'Alabama', 'Grant Applicant'),
#  ('Carson Lindsey', 'American Indian or Alaska Native', '1-715-578-1870', 'Quisque@fringilla.ca', 'Oregon', 'Loan Applicant'),
#  ('Carter Fulton', 'Black or African American', '1-840-451-1549', 'accumsan.laoreet.ipsum@imperdieterat.co.uk', 'Montana', 'Loan Applicant'),
#  ('Carter Robbins', 'American Indian or Alaska Native', '1-722-832-2431', 'In.lorem@eleifendnuncrisus.co.uk', 'Maine', 'Grant Applicant'),
#  ('Caryn Nicholson', 'Middle Eastern', '1-600-205-0140', 'magna.a@Ut.org', 'Michigan', 'Grant Applicant'),
#  ('Cassandra Pacheco', 'American Indian or Alaska Native', '1-767-138-9365', 'dictum.eleifend@pretium.com', 'Alabama', 'Grant Applicant'),
#  ('Castor Reese', 'Native Hawaiian or Other Pacific Islander', '1-102-245-7104', 'dapibus@felisDonectempor.ca', 'Maine', 'Grant Applicant'),
#  ('Celeste Hines', 'Asian', '1-640-124-3752', 'ullamcorper@fermentumvel.org', 'Montana', 'Loan Applicant'),
#  ('Chadwick Wolf', 'Hispanic or Latinx', '1-803-151-3338', 'amet.risus.Donec@sit.net', 'Texas', 'Loan Applicant'),
#  ('Chancellor Schwartz', 'Hispanic or Latinx', '1-328-652-9144', 'fringilla.Donec@risusNunc.com', 'Nebraska', 'Loan Applicant'),
#  ('Chanda Francis', 'Middle Eastern', '1-640-626-6179', 'velit.dui@NulladignissimMaecenas.edu', 'Wisconsin', 'Grant Applicant'),
#  ('Chantale Chambers', 'Asian', '1-792-715-5372', 'semper.dui@aneque.edu', 'Texas', 'Loan Applicant'),
#  ('Charde Reese', 'Asian', '1-905-318-5563', 'pretium@tempordiam.org', 'Mississippi', 'Grant Applicant'),
#  ('Charde Travis', 'Hispanic or Latinx', '1-754-422-4736', 'semper.Nam.tempor@miAliquam.co.uk', 'Indiana', 'Grant Applicant'),
#  ('Charissa Tanner', 'Hispanic or Latinx', '1-792-644-4510', 'Fusce@et.org', 'Missouri', 'Grant Applicant'),
#  ('Charles Graham', 'Asian', '1-127-594-6587', 'eros.Nam@blandit.com', 'Florida', 'Grant Applicant'),
#  ('Chava Good', 'Black or African American', '1-250-144-0297', 'malesuada.Integer@posuereat.co.uk', 'Kentucky', 'Loan Applicant'),
#  ('Chelsea Reyes', 'Native Hawaiian or Other Pacific Islander', '1-369-974-4760', 'In@gravida.com', 'Alabama', 'Loan Applicant'),
#  ('Cheryl Mays', 'Black or African American', '1-107-660-7218', 'iaculis@nonlorem.net', 'Kentucky', 'Loan Applicant'),
#  ('Chester Summers', 'American Indian or Alaska Native', '1-933-238-6572', 'et@utpellentesqueeget.org', 'Georgia', 'Loan Applicant'),
#  ('Chiquita Carroll', 'Hispanic or Latinx', '1-441-622-0707', 'sed@egestas.org', 'Mississippi', 'Grant Applicant'),
#  ('Christen Bailey', 'American Indian or Alaska Native', '1-550-100-3458', 'laoreet@anteblandit.org', 'Colorado', 'Loan Applicant'),
#  ('Clare Carr', 'Middle Eastern', '1-228-750-7086', 'malesuada@enimNunc.com', 'Minnesota', 'Grant Applicant'),
#  ('Clayton Hodge', 'Hispanic or Latinx', '1-819-273-9325', 'at.libero.Morbi@egestasAliquam.org', 'Idaho', 'Loan Applicant'),
#  ('Clementine Wilson', 'Asian', '1-861-140-8781', 'gravida.nunc.sed@egettinciduntdui.org', 'Iowa', 'Loan Applicant'),
#  ('Clinton Webb', 'Hispanic or Latinx', '1-540-641-1112', 'ullamcorper.Duis.at@Quisquefringilla.net', 'Pennsylvania', 'Loan Applicant'),
#  ('Clio Sanford', 'Middle Eastern', '1-908-430-8259', 'arcu@Phasellusnulla.net', 'Virginia', 'Loan Applicant'),
#  ('Coby Simpson', 'Black or African American', '1-465-954-2158', 'Nulla@nislsemconsequat.ca', 'Alaska', 'Loan Applicant'),
#  ('Colby Huff', 'Black or African American', '1-472-295-2428', 'Cras@acurnaUt.edu', 'Alabama', 'Grant Applicant'),
#  ('Colt Acosta', 'Black or African American', '1-343-446-9091', 'elit.erat@nequeNullamnisl.net', 'Colorado', 'Loan Applicant'),
#  ('Conan Bullock', 'Middle Eastern', '1-876-339-3361', 'in.sodales@duilectusrutrum.co.uk', 'Nebraska', 'Grant Applicant'),
#  ('Conan Huff', 'Black or African American', '1-327-509-1277', 'rutrum.Fusce@ullamcorper.ca', 'Kentucky', 'Loan Applicant'),
#  ('Conan Sparks', 'Black or African American', '1-310-936-8826', 'cursus.non@malesuadavelconvallis.edu', 'Oklahoma', 'Grant Applicant'),
#  ('Connor Goff', 'American Indian or Alaska Native', '1-490-514-9996', 'quam.dignissim@enimcondimentumeget.org', 'Maryland', 'Grant Applicant'),
#  ('Connor Nieves', 'American Indian or Alaska Native', '1-943-943-8808', 'consectetuer.adipiscing@nisiAeneaneget.co.uk', 'Pennsylvania', 'Loan Applicant'),
#  ('Constance Conner', 'American Indian or Alaska Native', '1-777-463-5387', 'turpis.egestas.Fusce@Phasellusfermentum.edu', 'Colorado', 'Grant Applicant'),
#  ('Cooper Mayer', 'Hispanic or Latinx', '1-310-824-3199', 'gravida@lacusQuisque.ca', 'Maryland', 'Grant Applicant'),
#  ('Dahlia Frost', 'Native Hawaiian or Other Pacific Islander', '1-227-256-2331', 'vulputate@ligula.net', 'Georgia', 'Loan Applicant'),
#  ('Dahlia Owen', 'American Indian or Alaska Native', '1-842-633-9805', 'ante@elitAliquam.ca', 'Nevada', 'Loan Applicant'),
#  ('Dai Sweet', 'Asian', '1-269-904-7624', 'Suspendisse.tristique@Cum.com', 'California', 'Loan Applicant'),
#  ('Dale Alvarez', 'Asian', '1-811-757-4294', 'nec.luctus.felis@Cras.net', 'Oregon', 'Loan Applicant'),
#  ('Damian French', 'Black or African American', '1-958-751-0026', 'Duis.cursus.diam@enim.org', 'Kentucky', 'Grant Applicant'),
#  ('Dana Mason', 'Black or African American', '1-122-688-5881', 'ridiculus.mus@laciniaatiaculis.com', 'Tennessee', 'Grant Applicant'),
#  ('Dane Hensley', 'Hispanic or Latinx', '1-745-451-9858', 'inceptos.hymenaeos.Mauris@vellectusCum.net', 'Delaware', 'Loan Applicant'),
#  ('Dante Black', 'Asian', '1-171-172-5856', 'Vestibulum.accumsan@ac.ca', 'Wisconsin', 'Loan Applicant'),
#  ('Dara Hunter', 'Hispanic or Latinx', '1-506-563-9682', 'facilisi.Sed.neque@SeddictumProin.ca', 'Maryland', 'Grant Applicant'),
#  ('Darius Morgan', 'Middle Eastern', '1-132-100-9990', 'magna.et@mauris.org', 'Minnesota', 'Grant Applicant'),
#  ('Darryl Castillo', 'Native Hawaiian or Other Pacific Islander', '1-179-490-1093', 'vel@interdumligulaeu.com', 'Virginia', 'Grant Applicant'),
#  ('Darryl Waters', 'Hispanic or Latinx', '1-373-270-5643', 'nisi.Aenean.eget@Morbiquisurna.edu', 'Washington', 'Grant Applicant'),
#  ('Daryl Dunlap', 'Native Hawaiian or Other Pacific Islander', '1-839-155-8781', 'vitae.posuere@hendreritDonec.org', 'Connecticut', 'Grant Applicant'),
#  ('Dean Lowe', 'Native Hawaiian or Other Pacific Islander', '1-281-541-6371', 'id.erat.Etiam@Quisque.edu', 'Oklahoma', 'Grant Applicant'),
#  ('Deanna Byers', 'Hispanic or Latinx', '1-834-199-2639', 'at@conubianostra.com', 'Arizona', 'Loan Applicant'),
#  ('Deborah Acosta', 'Native Hawaiian or Other Pacific Islander', '1-593-603-4474', 'Pellentesque@porta.ca', 'Delaware', 'Grant Applicant'),
#  ('Debra Erickson', 'American Indian or Alaska Native', '1-494-671-8311', 'Proin.eget.odio@Suspendisseeleifend.com', 'Idaho', 'Grant Applicant'),
#  ('Deirdre Walters', 'Middle Eastern', '1-536-253-8220', 'diam.Proin.dolor@eunullaat.org', 'Idaho', 'Loan Applicant'),
#  ('Demetrius Martin', 'American Indian or Alaska Native', '1-590-199-1682', 'purus.ac.tellus@tempus.ca', 'Tennessee', 'Loan Applicant'),
#  ('Demetrius Mcneil', 'Native Hawaiian or Other Pacific Islander', '1-718-866-1262', 'tortor.dictum.eu@risus.edu', 'Alabama', 'Loan Applicant'),
#  ('Demetrius Webb', 'Hispanic or Latinx', '1-729-636-1046', 'ac@sedconsequat.net', 'Tennessee', 'Grant Applicant'),
#  ('Demetrius White', 'Native Hawaiian or Other Pacific Islander', '1-480-326-9793', 'sem.molestie@adipiscing.org', 'Missouri', 'Loan Applicant'),
#  ('Dennis Cherry', 'Asian', '1-447-646-4090', 'Fusce.mollis@eget.net', 'Washington', 'Grant Applicant'),
#  ('Denton Bright', 'Black or African American', '1-580-463-7365', 'natoque.penatibus@Vivamusmolestiedapibus.co.uk', 'Utah', 'Grant Applicant'),
#  ('Desirae Snow', 'Black or African American', '1-813-115-5445', 'egestas.ligula.Nullam@Duis.com', 'Illinois', 'Grant Applicant'),
#  ('Devin Daugherty', 'Hispanic or Latinx', '1-235-551-5990', 'Lorem@Praesent.com', 'Virginia', 'Grant Applicant'),
#  ('Diana Molina', 'Middle Eastern', '1-204-105-1355', 'dui.Fusce@milacinia.edu', 'Connecticut', 'Grant Applicant'),
#  ('Dieter Holman', 'Black or African American', '1-373-116-2944', 'cursus.diam@loremegetmollis.ca', 'Connecticut', 'Grant Applicant'),
#  ('Dominic Little', 'Hispanic or Latinx', '1-271-955-7381', 'nascetur.ridiculus.mus@cursusnon.edu', 'Florida', 'Grant Applicant'),
#  ('Dominique Duncan', 'Middle Eastern', '1-687-835-3072', 'eget.laoreet.posuere@Pellentesque.org', 'Nebraska', 'Grant Applicant'),
#  ('Donna Koch', 'Hispanic or Latinx', '1-192-911-1894', 'vel.lectus@necmollis.com', 'Georgia', 'Grant Applicant'),
#  ('Dora Everett', 'Asian', '1-300-755-4505', 'congue@arcuSed.net', 'Montana', 'Grant Applicant'),
#  ('Dora Navarro', 'Black or African American', '1-864-770-8260', 'nonummy.ac@anteblanditviverra.edu', 'Wisconsin', 'Loan Applicant'),
#  ('Dorian Morrison', 'Middle Eastern', '1-908-519-6850', 'interdum.libero.dui@enim.org', 'Georgia', 'Grant Applicant'),
#  ('Doris Snow', 'Black or African American', '1-976-669-8501', 'dictum.mi@dui.org', 'Nevada', 'Grant Applicant'),
#  ('Driscoll Waller', 'Black or African American', '1-649-347-3340', 'risus@sit.net', 'Kansas', 'Grant Applicant'),
#  ('Duncan Castro', 'Native Hawaiian or Other Pacific Islander', '1-794-533-0426', 'magna@vulputateullamcorpermagna.com', 'Washington', 'Loan Applicant'),
#  ('Dustin Gonzales', 'Middle Eastern', '1-981-115-3104', 'luctus.ut@perinceptos.org', 'Texas', 'Loan Applicant'),
#  ('Dustin Sharpe', 'Asian', '1-563-824-9807', 'dictum.eu@non.org', 'Pennsylvania', 'Grant Applicant'),
#  ('Eagan Levine', 'Hispanic or Latinx', '1-611-170-0009', 'arcu@egestasDuisac.org', 'Idaho', 'Loan Applicant'),
#  ('Echo Ortega', 'Black or African American', '1-742-798-7530', 'mi.Duis@aliquet.ca', 'Texas', 'Loan Applicant'),
#  ('Edan Howe', 'Native Hawaiian or Other Pacific Islander', '1-554-766-6312', 'eu@nec.org', 'Utah', 'Grant Applicant'),
#  ('Edward Wall', 'Middle Eastern', '1-585-405-2175', 'eu.eleifend.nec@nuncQuisque.ca', 'Vermont', 'Loan Applicant'),
#  ('Eleanor Mcintosh', 'Native Hawaiian or Other Pacific Islander', '1-863-406-5480', 'tellus.Aenean@dolorquam.ca', 'Ohio', 'Grant Applicant'),
#  ('Eliana Blackburn', 'American Indian or Alaska Native', '1-371-306-7958', 'orci.tincidunt.adipiscing@magnaNam.ca', 'Utah', 'Loan Applicant'),
#  ('Elijah Everett', 'Hispanic or Latinx', '1-738-937-9902', 'facilisis.facilisis@montesnasceturridiculus.edu', 'Oregon', 'Grant Applicant'),
#  ('Elizabeth Leon', 'Native Hawaiian or Other Pacific Islander', '1-229-415-5123', 'tellus.id@tortordictumeu.org', 'Florida', 'Grant Applicant'),
#  ('Ella Avery', 'American Indian or Alaska Native', '1-331-509-2938', 'aptent.taciti@ornare.com', 'Mississippi', 'Loan Applicant'),
#  ('Elliott Harmon', 'Native Hawaiian or Other Pacific Islander', '1-201-584-8930', 'tristique.pharetra.Quisque@antedictum.org', 'Maryland', 'Grant Applicant'),
#  ('Elmo Humphrey', 'Middle Eastern', '1-503-578-1451', 'porttitor.interdum.Sed@egestasnuncsed.net', 'Nevada', 'Grant Applicant'),
#  ('Elton Cox', 'Native Hawaiian or Other Pacific Islander', '1-476-330-3796', 'nec@euultrices.edu', 'Idaho', 'Loan Applicant'),
#  ('Elton Jefferson', 'Asian', '1-909-545-5829', 'Aliquam.adipiscing@tinciduntnunc.ca', 'Nevada', 'Grant Applicant'),
#  ('Elvis Stanley', 'Middle Eastern', '1-563-762-8669', 'tincidunt.vehicula.risus@tortorNunc.org', 'Delaware', 'Grant Applicant'),
#  ('Emery Yang', 'Native Hawaiian or Other Pacific Islander', '1-144-773-8104', 'quam@necligulaconsectetuer.net', 'Minnesota', 'Grant Applicant'),
#  ('Emily Atkins', 'Asian', '1-621-710-8830', 'adipiscing.lobortis@metus.ca', 'Mississippi', 'Grant Applicant'),
#  ('Emily Morris', 'Middle Eastern', '1-772-725-0263', 'adipiscing.elit@estMauriseu.ca', 'Vermont', 'Loan Applicant'),
#  ('Emmanuel Peck', 'Native Hawaiian or Other Pacific Islander', '1-361-503-1870', 'dolor.Donec@eratvolutpatNulla.co.uk', 'Missouri', 'Grant Applicant'),
#  ('Erasmus Buckley', 'Native Hawaiian or Other Pacific Islander', '1-784-304-3422', 'velit.Aliquam.nisl@congue.net', 'Alaska', 'Loan Applicant'),
#  ('Erasmus James', 'American Indian or Alaska Native', '1-664-231-4437', 'faucibus.ut.nulla@mus.co.uk', 'Hawaii', 'Loan Applicant'),
#  ('Eric Clemons', 'Hispanic or Latinx', '1-838-181-4909', 'gravida.non@quamdignissimpharetra.ca', 'California', 'Loan Applicant'),
#  ('Eric Vinson', 'Native Hawaiian or Other Pacific Islander', '1-286-392-5445', 'sapien.Nunc.pulvinar@vitaeodiosagittis.ca', 'Alabama', 'Loan Applicant'),
#  ('Erich Sellers', 'Native Hawaiian or Other Pacific Islander', '1-446-957-3985', 'est.ac@amet.org', 'Tennessee', 'Grant Applicant'),
#  ('Erin Cotton', 'Middle Eastern', '1-446-869-9534', 'sed@idlibero.net', 'Ohio', 'Loan Applicant'),
#  ('Ethan Payne', 'Hispanic or Latinx', '1-217-831-4454', 'eu.tempor@maurisipsum.com', 'Montana', 'Loan Applicant'),
#  ('Evan Woodard', 'Asian', '1-156-452-2313', 'pede.malesuada.vel@suscipitest.org', 'Florida', 'Loan Applicant'),
#  ('Eve Gilmore', 'American Indian or Alaska Native', '1-130-587-5160', 'ligula@Curabiturutodio.edu', 'Delaware', 'Grant Applicant'),
#  ('Eve Marsh', 'Native Hawaiian or Other Pacific Islander', '1-692-363-0406', 'lectus@Fuscemilorem.co.uk', 'Maine', 'Loan Applicant'),
#  ('Ezekiel Estrada', 'Native Hawaiian or Other Pacific Islander', '1-620-587-8553', 'ullamcorper.velit@etmagnisdis.com', 'Minnesota', 'Grant Applicant'),
#  ('Faith Boone', 'American Indian or Alaska Native', '1-690-813-8613', 'lobortis@mi.ca', 'Delaware', 'Grant Applicant'),
#  ('Fallon Arnold', 'Native Hawaiian or Other Pacific Islander', '1-823-442-2750', 'Nulla.eu@erat.net', 'Maryland', 'Grant Applicant'),
#  ('Felix Aguilar', 'American Indian or Alaska Native', '1-231-777-5576', 'interdum@quisdiamluctus.edu', 'Indiana', 'Loan Applicant'),
#  ('Felix Strong', 'Black or African American', '1-874-966-8635', 'torquent.per.conubia@magnatellus.co.uk', 'Connecticut', 'Loan Applicant'),
#  ('Ferdinand Hardy', 'American Indian or Alaska Native', '1-109-210-0575', 'mattis.semper@semmolestiesodales.org', 'Iowa', 'Grant Applicant'),
#  ('Ferdinand Mitchell', 'American Indian or Alaska Native', '1-334-703-3375', 'enim.Etiam@musDonecdignissim.org', 'Arizona', 'Loan Applicant'),
#  ('Ferris Shannon', 'Black or African American', '1-972-116-4792', 'Aenean@sitamet.edu', 'Texas', 'Loan Applicant'),
#  ('Fiona French', 'Native Hawaiian or Other Pacific Islander', '1-558-255-4984', 'neque.Sed@mauris.edu', 'Alabama', 'Grant Applicant'),
#  ('Flavia Savage', 'Hispanic or Latinx', '1-605-247-9672', 'tempus.non@convallisdolor.ca', 'Wyoming', 'Loan Applicant'),
#  ('Fletcher Anderson', 'American Indian or Alaska Native', '1-973-764-8311', 'Fusce.mollis@enimMaurisquis.org', 'Kentucky', 'Grant Applicant'),
#  ('Florence Sanders', 'Asian', '1-404-917-9310', 'in@liberoest.net', 'Michigan', 'Loan Applicant'),
#  ('Flynn Mccarty', 'Hispanic or Latinx', '1-513-349-5839', 'Nullam@Nulla.ca', 'Alaska', 'Loan Applicant'),
#  ('Flynn Webster', 'American Indian or Alaska Native', '1-996-125-8760', 'nec@Maurismolestiepharetra.edu', 'Illinois', 'Loan Applicant'),
#  ('Forrest Wilder', 'Black or African American', '1-634-294-1590', 'pharetra.sed.hendrerit@ligula.org', 'Washington', 'Grant Applicant'),
#  ('Francis Rodriguez', 'Asian', '1-173-811-3565', 'Cras.pellentesque@nectempusscelerisque.net', 'Texas', 'Loan Applicant'),
#  ('Fritz Lewis', 'Black or African American', '1-764-433-9364', 'dictum@ullamcorperDuis.ca', 'Alaska', 'Grant Applicant'),
#  ('Fuller Baird', 'Asian', '1-634-220-1551', 'eget.ipsum@non.edu', 'Oregon', 'Grant Applicant'),
#  ('Fuller Patel', 'Asian', '1-992-353-5851', 'arcu.Vestibulum@etmalesuada.edu', 'Michigan', 'Grant Applicant'),
#  ('Fulton Sargent', 'American Indian or Alaska Native', '1-670-109-0562', 'Etiam.gravida.molestie@vulputatenisi.co.uk', 'Colorado', 'Grant Applicant'),
#  ('Gail Mullen', 'Hispanic or Latinx', '1-898-367-8955', 'velit.dui.semper@vitaeerat.edu', 'Indiana', 'Loan Applicant'),
#  ('Galena Howe', 'Asian', '1-486-135-3626', 'volutpat.ornare@pellentesquemassalobortis.com', 'Texas', 'Grant Applicant'),
#  ('Garrett Martinez', 'Middle Eastern', '1-770-661-4121', 'cursus.vestibulum.Mauris@Aliquam.co.uk', 'Kansas', 'Loan Applicant'),
#  ('Garrison Rios', 'Middle Eastern', '1-177-269-3225', 'accumsan@eu.co.uk', 'Kentucky', 'Grant Applicant'),
#  ('Garth Hutchinson', 'Asian', '1-827-227-1072', 'ac.libero@pellentesque.net', 'Tennessee', 'Grant Applicant'),
#  ('Gavin Gross', 'Hispanic or Latinx', '1-915-479-3632', 'nulla@idrisus.net', 'Minnesota', 'Grant Applicant'),
#  ('Gay Conrad', 'Middle Eastern', '1-543-333-4727', 'nunc.ullamcorper@odio.ca', 'Arizona', 'Grant Applicant'),
#  ('Gay Pearson', 'Asian', '1-675-901-9725', 'mauris.Suspendisse@habitant.ca', 'Texas', 'Grant Applicant'),
#  ('Genevieve Rocha', 'Black or African American', '1-160-414-8547', 'velit@luctus.co.uk', 'Delaware', 'Grant Applicant'),
#  ('Geoffrey Anderson', 'Black or African American', '1-572-572-4274', 'Fusce.mi@idmagnaet.co.uk', 'Ohio', 'Grant Applicant'),
#  ('Gil Beck', 'Black or African American', '1-523-216-2553', 'Nullam.ut@nibhlaciniaorci.ca', 'Alabama', 'Loan Applicant'),
#  ('Gil Mcgee', 'Asian', '1-636-628-9048', 'tristique.senectus.et@Nam.ca', 'Connecticut', 'Loan Applicant'),
#  ('Ginger Sutton', 'Hispanic or Latinx', '1-347-221-8790', 'fermentum.metus@nulla.co.uk', 'Iowa', 'Grant Applicant'),
#  ('Grady Hoover', 'Native Hawaiian or Other Pacific Islander', '1-667-653-5998', 'metus.eu.erat@molestie.ca', 'Washington', 'Grant Applicant'),
#  ('Grady Velasquez', 'Hispanic or Latinx', '1-365-382-0238', 'urna.Ut.tincidunt@faucibus.com', 'Utah', 'Loan Applicant'),
#  ('Graiden Marsh', 'Middle Eastern', '1-109-991-5056', 'dictum@Aenean.edu', 'Maryland', 'Grant Applicant'),
#  ('Gray Juarez', 'Middle Eastern', '1-697-483-6759', 'auctor.quis.tristique@litoratorquentper.co.uk', 'Hawaii', 'Grant Applicant'),
#  ('Guy Carter', 'Black or African American', '1-791-194-5245', 'dictum.cursus@aliquet.org', 'Vermont', 'Grant Applicant'),
#  ('Gwendolyn Copeland', 'Hispanic or Latinx', '1-525-346-4086', 'aliquet@nisinibhlacinia.edu', 'Alaska', 'Grant Applicant'),
#  ('Gwendolyn Meyer', 'Asian', '1-523-691-7677', 'Pellentesque.tincidunt.tempus@Integermollis.net', 'Indiana', 'Loan Applicant'),
#  ('Hadley Singleton', 'Native Hawaiian or Other Pacific Islander', '1-455-184-3617', 'libero@inconsequat.co.uk', 'Delaware', 'Loan Applicant'),
#  ('Halee Hodge', 'Black or African American', '1-992-983-5531', 'luctus.aliquet@ullamcorperDuis.co.uk', 'Wisconsin', 'Grant Applicant'),
#  ('Hamilton Leblanc', 'Asian', '1-433-773-5478', 'sed.hendrerit.a@a.com', 'California', 'Grant Applicant'),
#  ('Hamilton Nelson', 'American Indian or Alaska Native', '1-587-912-0858', 'semper.tellus@rhoncusid.org', 'Kentucky', 'Grant Applicant'),
#  ('Hamilton Nichols', 'Black or African American', '1-497-181-0146', 'Etiam.vestibulum.massa@parturient.edu', 'Washington', 'Grant Applicant'),
#  ('Hamish Sawyer', 'Asian', '1-161-570-3559', 'Sed.et.libero@nunc.net', 'Arizona', 'Grant Applicant'),
#  ('Hannah Becker', 'Hispanic or Latinx', '1-517-235-3332', 'natoque@sociisnatoquepenatibus.edu', 'Tennessee', 'Grant Applicant'),
#  ('Harding Levine', 'Native Hawaiian or Other Pacific Islander', '1-645-112-0233', 'at@ametorci.edu', 'Iowa', 'Grant Applicant'),
#  ('Hashim Adams', 'Hispanic or Latinx', '1-987-668-9372', 'at.fringilla.purus@arcuVestibulum.net', 'Wisconsin', 'Grant Applicant'),
#  ('Hayes Price', 'Asian', '1-672-680-7764', 'Aenean@Fuscedolorquam.org', 'Idaho', 'Grant Applicant'),
#  ('Hayfa Spencer', 'Middle Eastern', '1-800-306-5301', 'in@quis.ca', 'Kentucky', 'Grant Applicant'),
#  ('Hayley Noble', 'Native Hawaiian or Other Pacific Islander', '1-829-650-0919', 'consequat@vestibulumneceuismod.ca', 'Oregon', 'Grant Applicant'),
#  ('Hedda Goodman', 'Middle Eastern', '1-375-769-5995', 'ut.quam.vel@lectusjustoeu.net', 'Indiana', 'Grant Applicant'),
#  ('Hedda Mcgee', 'American Indian or Alaska Native', '1-874-662-6364', 'nunc@Praesent.org', 'Michigan', 'Grant Applicant'),
#  ('Herman Bird', 'Black or African American', '1-854-649-0088', 'arcu.et.pede@volutpatNullafacilisis.com', 'Virginia', 'Grant Applicant'),
#  ('Herman Short', 'Middle Eastern', '1-366-529-7159', 'arcu.eu.odio@enimgravida.ca', 'Alabama', 'Grant Applicant'),
#  ('Hermione Harrell', 'Middle Eastern', '1-258-156-5281', 'sollicitudin@ante.org', 'Alaska', 'Grant Applicant'),
#  ('Herrod Boone', 'Middle Eastern', '1-329-377-6986', 'ac.urna@sed.co.uk', 'Minnesota', 'Grant Applicant'),
#  ('Hilary Case', 'Asian', '1-530-748-2110', 'magna.Duis.dignissim@ametmassa.net', 'Missouri', 'Grant Applicant'),
#  ('Hilary Hardy', 'Hispanic or Latinx', '1-773-439-4754', 'Nulla@dolorquamelementum.org', 'Hawaii', 'Loan Applicant'),
#  ('Hillary Lewis', 'Native Hawaiian or Other Pacific Islander', '1-691-650-1202', 'risus.Donec@tempor.net', 'Delaware', 'Loan Applicant'),
#  ('Hiram Boyd', 'Hispanic or Latinx', '1-800-276-8388', 'lobortis@conubia.co.uk', 'Georgia', 'Loan Applicant'),
#  ('Hiram Riggs', 'American Indian or Alaska Native', '1-977-392-5794', 'litora@consequatenim.ca', 'Pennsylvania', 'Grant Applicant'),
#  ('Hiram Sanders', 'Native Hawaiian or Other Pacific Islander', '1-394-437-6163', 'dignissim.Maecenas.ornare@magna.ca', 'Oregon', 'Loan Applicant'),
#  ('Holmes Barlow', 'Black or African American', '1-887-934-9614', 'neque.vitae.semper@diamSeddiam.edu', 'Massachusetts', 'Loan Applicant'),
#  ('Holmes Wolf', 'Black or African American', '1-336-101-3484', 'ridiculus.mus.Donec@elitpellentesquea.co.uk', 'Oregon', 'Grant Applicant'),
#  ('Honorato Hicks', 'Middle Eastern', '1-145-137-7999', 'a@Morbi.ca', 'Texas', 'Grant Applicant'),
#  ('Honorato Slater', 'American Indian or Alaska Native', '1-619-312-3592', 'amet@suscipitest.co.uk', 'Ohio', 'Loan Applicant'),
#  ('Hop Rowland', 'Native Hawaiian or Other Pacific Islander', '1-154-942-9072', 'velit.eget@SuspendisseeleifendCras.ca', 'Maryland', 'Grant Applicant'),
#  ('Hope Park', 'American Indian or Alaska Native', '1-439-175-2487', 'Duis.dignissim@quam.edu', 'Georgia', 'Grant Applicant'),
#  ('Howard Lee', 'American Indian or Alaska Native', '1-124-752-9102', 'Integer@facilisisnon.com', 'Oklahoma', 'Loan Applicant'),
#  ('Hoyt Buchanan', 'Native Hawaiian or Other Pacific Islander', '1-105-839-5548', 'amet.faucibus@interdumNuncsollicitudin.co.uk', 'Hawaii', 'Grant Applicant'),
#  ('Hyacinth Chaney', 'Black or African American', '1-465-159-0713', 'ac.tellus@DuisgravidaPraesent.org', 'Virginia', 'Grant Applicant'),
#  ('Idola Wiggins', 'Native Hawaiian or Other Pacific Islander', '1-446-416-9829', 'Proin.nisl.sem@diamdictumsapien.com', 'Maine', 'Loan Applicant'),
#  ('Ignacia Miles', 'Middle Eastern', '1-622-841-9939', 'sem.elit@vel.org', 'Oklahoma', 'Grant Applicant'),
#  ('Ignatius Wolf', 'Middle Eastern', '1-405-964-1742', 'dolor.sit@malesuada.org', 'Texas', 'Grant Applicant'),
#  ('Iliana Glenn', 'Black or African American', '1-304-284-5615', 'justo.eu@In.co.uk', 'Iowa', 'Grant Applicant'),
#  ('Iliana Trujillo', 'Hispanic or Latinx', '1-217-560-1341', 'Nulla.aliquet.Proin@vulputaterisusa.net', 'Missouri', 'Loan Applicant'),
#  ('Illiana Burns', 'American Indian or Alaska Native', '1-909-467-9802', 'quis.lectus.Nullam@tincidunt.org', 'Idaho', 'Grant Applicant'),
#  ('Imani Hardy', 'Asian', '1-807-256-9556', 'eget.ipsum.Suspendisse@ametanteVivamus.ca', 'Louisiana', 'Grant Applicant'),
#  ('Imani Mullins', 'Hispanic or Latinx', '1-322-723-2898', 'amet@imperdiet.net', 'Alaska', 'Loan Applicant'),
#  ('Imani Stokes', 'Black or African American', '1-935-576-4833', 'ac.sem@eros.edu', 'Wyoming', 'Grant Applicant'),
#  ('Imogene Summers', 'Native Hawaiian or Other Pacific Islander', '1-400-770-3530', 'dignissim@pharetranibhAliquam.com', 'Georgia', 'Grant Applicant'),
#  ('Ina Walton', 'Native Hawaiian or Other Pacific Islander', '1-198-127-0531', 'lobortis.quis.pede@fringilla.edu', 'Maine', 'Loan Applicant'),
#  ('India Wright', 'Black or African American', '1-207-826-6632', 'arcu.iaculis.enim@gravida.net', 'Wyoming', 'Grant Applicant'),
#  ('Indira Kemp', 'Native Hawaiian or Other Pacific Islander', '1-860-214-0644', 'Cras.dictum.ultricies@sed.co.uk', 'Texas', 'Grant Applicant'),
#  ('Irene Best', 'American Indian or Alaska Native', '1-376-856-4867', 'sodales@eleifend.org', 'Alaska', 'Grant Applicant'),
#  ('Irene Stout', 'Asian', '1-586-785-0611', 'Fusce@Etiam.ca', 'Connecticut', 'Loan Applicant'),
#  ('Iris Nunez', 'Native Hawaiian or Other Pacific Islander', '1-151-706-8009', 'non.arcu@semegestas.co.uk', 'Connecticut', 'Grant Applicant'),
#  ('Isaac Lester', 'Asian', '1-782-366-1249', 'tempus.scelerisque.lorem@magna.edu', 'Vermont', 'Grant Applicant'),
#  ('Isaac Morin', 'Hispanic or Latinx', '1-259-932-6427', 'Aliquam.erat.volutpat@Nunc.org', 'Arizona', 'Loan Applicant'),
#  ('Isabella Lewis', 'American Indian or Alaska Native', '1-981-160-1057', 'tempus.mauris.erat@rutrumjustoPraesent.com', 'Arkansas', 'Loan Applicant'),
#  ('Isabelle Booker', 'Native Hawaiian or Other Pacific Islander', '1-446-985-5442', 'euismod.urna@nuncInat.edu', 'Minnesota', 'Grant Applicant'),
#  ('Isadora Roberts', 'Black or African American', '1-925-589-0008', 'Cras.vulputate@pedemalesuada.net', 'Vermont', 'Grant Applicant'),
#  ('Isaiah Koch', 'Middle Eastern', '1-503-226-0817', 'ac.mattis@ornaretortorat.com', 'Georgia', 'Grant Applicant'),
#  ('Ishmael Koch', 'Middle Eastern', '1-453-799-5787', 'Donec.egestas@sem.com', 'Oklahoma', 'Grant Applicant'),
#  ('Ivory Hampton', 'Middle Eastern', '1-184-964-4600', 'Cum.sociis.natoque@loremegetmollis.net', 'Alabama', 'Grant Applicant'),
#  ('Ivory Vasquez', 'Black or African American', '1-487-444-4075', 'consectetuer.mauris@dictumProineget.edu', 'Wyoming', 'Loan Applicant'),
#  ('Jacob Torres', 'Middle Eastern', '1-654-398-4616', 'a@ultricies.org', 'Minnesota', 'Grant Applicant'),
#  ('Jada Sherman', 'Hispanic or Latinx', '1-314-519-1410', 'eu@feugiatmetussit.co.uk', 'Indiana', 'Grant Applicant'),
#  ('Jade Higgins', 'Middle Eastern', '1-824-536-0727', 'quis.pede@bibendumullamcorperDuis.edu', 'Montana', 'Loan Applicant'),
#  ('Jamal Deleon', 'Native Hawaiian or Other Pacific Islander', '1-787-391-1537', 'Ut@nec.ca', 'Mississippi', 'Loan Applicant'),
#  ('Jamal May', 'Native Hawaiian or Other Pacific Islander', '1-445-944-1795', 'vehicula.risus.Nulla@molestie.ca', 'Massachusetts', 'Grant Applicant'),
#  ('Jamalia Freeman', 'Black or African American', '1-933-257-3111', 'mauris@Fusce.edu', 'Vermont', 'Grant Applicant'),
#  ('Jamalia Randall', 'Hispanic or Latinx', '1-806-585-5271', 'hendrerit.neque.In@et.co.uk', 'Kentucky', 'Grant Applicant'),
#  ('James Simpson', 'Hispanic or Latinx', '1-924-213-2914', 'erat.in@ligulaNullam.co.uk', 'Mississippi', 'Loan Applicant'),
#  ('Jana Elliott', 'Asian', '1-149-315-1578', 'eget.ipsum.Suspendisse@euismodenimEtiam.co.uk', 'California', 'Grant Applicant'),
#  ('Jane David', 'Hispanic or Latinx', '1-207-233-1663', 'libero.Proin.mi@loremegetmollis.org', 'Wyoming', 'Grant Applicant'),
#  ('Jared Cervantes', 'Native Hawaiian or Other Pacific Islander', '1-606-517-9397', 'non@lacinia.org', 'Oregon', 'Grant Applicant'),
#  ('Jason Carlson', 'Middle Eastern', '1-154-536-9999', 'est.Nunc.ullamcorper@Maecenasiaculis.net', 'Illinois', 'Grant Applicant'),
#  ('Jelani Sparks', 'Middle Eastern', '1-991-854-8177', 'Cras.sed.leo@Inscelerisque.org', 'Mississippi', 'Loan Applicant'),
#  ('Jena Holloway', 'American Indian or Alaska Native', '1-380-102-1208', 'euismod@Quisqueporttitoreros.ca', 'Louisiana', 'Loan Applicant'),
#  ('Jennifer Wagner', 'Hispanic or Latinx', '1-719-724-5061', 'libero.dui@Donecfelisorci.co.uk', 'Illinois', 'Grant Applicant'),
#  ('Jeremy Barr', 'Black or African American', '1-289-906-5518', 'Phasellus@sodalespurusin.com', 'Wisconsin', 'Grant Applicant'),
#  ('Jermaine Newman', 'Middle Eastern', '1-219-261-5028', 'ac.risus.Morbi@Aliquamgravidamauris.edu', 'Hawaii', 'Loan Applicant'),
#  ('Jerry Castro', 'Middle Eastern', '1-369-195-0933', 'quis@diamvel.org', 'Kentucky', 'Grant Applicant'),
#  ('Jerry Haley', 'Middle Eastern', '1-335-355-2205', 'scelerisque.neque.sed@Pellentesqueultriciesdignissim.org', 'Mississippi', 'Grant Applicant'),
#  ('Jescie Freeman', 'Middle Eastern', '1-602-688-2539', 'eu@eu.ca', 'Arkansas', 'Grant Applicant'),
#  ('Jescie Marks', 'Asian', '1-580-450-7022', 'sed@tristiquepellentesquetellus.org', 'Washington', 'Loan Applicant'),
#  ('Jesse Carlson', 'American Indian or Alaska Native', '1-510-345-9441', 'mollis.vitae.posuere@consectetueradipiscing.edu', 'Colorado', 'Grant Applicant'),
#  ('Jessica Calderon', 'Asian', '1-892-656-9404', 'et.tristique@lobortis.edu', 'Connecticut', 'Loan Applicant'),
#  ('Jin Burt', 'Hispanic or Latinx', '1-559-760-4284', 'cursus@Suspendissealiquetsem.edu', 'Oklahoma', 'Grant Applicant'),
#  ('Jin Gay', 'American Indian or Alaska Native', '1-589-818-1607', 'Donec@luctusipsumleo.ca', 'Tennessee', 'Loan Applicant'),
#  ('Joan Cooper', 'Native Hawaiian or Other Pacific Islander', '1-752-145-7321', 'nostra@Quisquefringillaeuismod.ca', 'California', 'Loan Applicant'),
#  ('Joel Barr', 'Native Hawaiian or Other Pacific Islander', '1-623-706-4917', 'euismod@loremut.net', 'Vermont', 'Grant Applicant'),
#  ('Jolene Wallace', 'Native Hawaiian or Other Pacific Islander', '1-844-474-0786', 'neque.non@inmagna.ca', 'Kentucky', 'Grant Applicant'),
#  ('Jordan Stanton', 'Native Hawaiian or Other Pacific Islander', '1-565-726-7563', 'quis.diam.luctus@enimNunc.net', 'Kansas', 'Loan Applicant'),
#  ('Jorden Chandler', 'Hispanic or Latinx', '1-437-158-2645', 'sapien.cursus@purus.net', 'Washington', 'Loan Applicant'),
#  ('Joseph Ochoa', 'Asian', '1-193-334-2731', 'nisi.nibh.lacinia@sollicitudin.edu', 'Tennessee', 'Loan Applicant'),
#  ('Joshua Rutledge', 'Black or African American', '1-818-616-8253', 'Donec@malesuada.net', 'Washington', 'Loan Applicant'),
#  ('Judah Townsend', 'Black or African American', '1-267-367-1605', 'luctus.ut.pellentesque@ridiculusmus.co.uk', 'Ohio', 'Grant Applicant'),
#  ('Julie Barr', 'Native Hawaiian or Other Pacific Islander', '1-241-914-9664', 'Donec@per.net', 'Hawaii', 'Loan Applicant'),
#  ('Justin Tyler', 'Native Hawaiian or Other Pacific Islander', '1-942-950-1306', 'Nam.interdum.enim@Vivamusnibh.net', 'California', 'Loan Applicant'),
#  ('Justina Mcdaniel', 'Black or African American', '1-790-149-3920', 'quis@necurnaet.com', 'Delaware', 'Loan Applicant'),
#  ('Justine Guy', 'Black or African American', '1-217-977-9203', 'malesuada.fringilla@urna.net', 'Maine', 'Loan Applicant'),
#  ('Kamal Sparks', 'Native Hawaiian or Other Pacific Islander', '1-398-227-9358', 'pede@MorbimetusVivamus.co.uk', 'Alaska', 'Loan Applicant'),
#  ('Kameko Baird', 'Native Hawaiian or Other Pacific Islander', '1-121-774-1823', 'commodo@massanon.ca', 'Oklahoma', 'Loan Applicant'),
#  ('Kameko Blevins', 'Black or African American', '1-626-786-4390', 'ante@libero.co.uk', 'Massachusetts', 'Loan Applicant'),
#  ('Kameko Carver', 'American Indian or Alaska Native', '1-763-696-3353', 'luctus.Curabitur.egestas@semPellentesque.org', 'Ohio', 'Grant Applicant'),
#  ('Kameko Castillo', 'Hispanic or Latinx', '1-240-682-8871', 'magnis@Nunc.co.uk', 'Kansas', 'Grant Applicant'),
#  ('Karen Boyd', 'Middle Eastern', '1-980-635-9927', 'lectus.pede@lobortisquama.ca', 'Utah', 'Grant Applicant'),
#  ('Karen Nixon', 'Middle Eastern', '1-303-164-9160', 'ipsum@sitamet.com', 'Utah', 'Grant Applicant'),
#  ('Karyn Carr', 'Native Hawaiian or Other Pacific Islander', '1-366-387-3599', 'sit.amet.luctus@erosnectellus.org', 'Colorado', 'Grant Applicant'),
#  ('Karyn Osborne', 'Asian', '1-719-359-7652', 'amet.risus@ipsumSuspendisse.ca', 'Virginia', 'Grant Applicant'),
#  ('Kaseem Steele', 'Asian', '1-592-927-4683', 'sapien@Integerinmagna.org', 'Wyoming', 'Loan Applicant'),
#  ('Kasper Savage', 'Hispanic or Latinx', '1-135-213-3632', 'laoreet.posuere.enim@placerat.org', 'Wyoming', 'Loan Applicant'),
# ...
#  ('Robin Valdez', 'American Indian or Alaska Native', '1-401-741-1676', 'ut@necurna.com', 'Missouri', 'Grant Applicant'),
#  ('Rooney Lee', 'Black or African American', '1-565-479-7613', 'luctus.Curabitur.egestas@enimnisl.org', 'Washington', 'Grant Applicant'),
#  ('Rosalyn Vazquez', 'Asian', '1-229-580-3135', 'sed.dui.Fusce@hendreritDonecporttitor.ca', 'Oregon', 'Loan Applicant'),
#  ('Ross Nichols', 'American Indian or Alaska Native', '1-603-530-5623', 'Nullam.suscipit.est@taciti.org', 'Wyoming', 'Grant Applicant'),
#  ('Ruby Olsen', 'Asian', '1-614-452-3317', 'Integer@non.edu', 'Utah', 'Loan Applicant'),
#  ('Russell Wolfe', 'Hispanic or Latinx', '1-394-787-6478', 'Nunc.mauris@pharetraQuisque.com', 'Michigan', 'Grant Applicant'),
#  ('Salvador Crawford', 'Black or African American', '1-861-300-5259', 'turpis.vitae.purus@sapiengravida.edu', 'Indiana', 'Loan Applicant'),
#  ('Samuel Lott', 'Black or African American', '1-383-969-9271', 'erat.Etiam@molestieorci.com', 'Alaska', 'Grant Applicant'),
#  ('Sara Adkins', 'Black or African American', '1-458-457-6755', 'posuere.enim.nisl@dui.org', 'Maine', 'Loan Applicant'),
#  ('Sarah Mcmahon', 'Native Hawaiian or Other Pacific Islander', '1-418-512-9530', 'est.arcu@sit.net', 'Florida', 'Grant Applicant'),
#  ('Sawyer Osborn', 'Native Hawaiian or Other Pacific Islander', '1-535-225-7598', 'cursus.Nunc@sit.edu', 'Idaho', 'Grant Applicant'),
#  ('Sean Weber', 'Middle Eastern', '1-434-650-0292', 'vulputate.mauris.sagittis@tristique.ca', 'Pennsylvania', 'Loan Applicant'),
#  ('September Baldwin', 'Asian', '1-985-859-9397', 'urna.Ut.tincidunt@fermentum.com', 'Idaho', 'Loan Applicant'),
#  ('September Hale', 'Black or African American', '1-690-293-9037', 'non@euismodestarcu.org', 'Kansas', 'Grant Applicant'),
#  ('Serena Sexton', 'American Indian or Alaska Native', '1-170-446-8307', 'nunc.nulla@adipiscingligulaAenean.com', 'Mississippi', 'Grant Applicant'),
#  ('Shad Cox', 'Black or African American', '1-739-996-2345', 'senectus@purus.net', 'Texas', 'Loan Applicant'),
#  ('Shad Green', 'Hispanic or Latinx', '1-713-708-1464', 'urna.suscipit.nonummy@Duisrisusodio.edu', 'Pennsylvania', 'Grant Applicant'),
#  ('Shana Macdonald', 'American Indian or Alaska Native', '1-397-162-1402', 'vehicula@molestie.ca', 'Indiana', 'Grant Applicant'),
#  ('Shana Steele', 'Hispanic or Latinx', '1-225-435-5983', 'dolor.egestas.rhoncus@Aeneangravida.net', 'Hawaii', 'Loan Applicant'),
#  ('Sharon Richards', 'Native Hawaiian or Other Pacific Islander', '1-834-227-4715', 'egestas.blandit@quama.edu', 'Massachusetts', 'Loan Applicant'),
#  ('Shelley Stark', 'Middle Eastern', '1-975-734-3238', 'sodales.elit@lorem.com', 'Louisiana', 'Loan Applicant'),
#  ('Shellie Rivers', 'Native Hawaiian or Other Pacific Islander', '1-603-827-4921', 'dignissim.lacus@eratvitae.ca', 'Utah', 'Grant Applicant'),
#  ('Shelly Gilbert', 'American Indian or Alaska Native', '1-846-886-4595', 'dolor@Loremipsum.edu', 'Missouri', 'Grant Applicant'),
#  ('Shoshana Carroll', 'Native Hawaiian or Other Pacific Islander', '1-113-651-5828', 'quis.arcu@felis.net', 'Oklahoma', 'Loan Applicant'),
#  ('Shoshana Washington', 'Hispanic or Latinx', '1-553-489-6884', 'bibendum.sed.est@dictumeu.co.uk', 'Florida', 'Loan Applicant'),
#  ('Signe Roman', 'Asian', '1-291-811-6197', 'sapien.imperdiet@euismodmauriseu.edu', 'Idaho', 'Grant Applicant'),
#  ('Silas Stevenson', 'Asian', '1-132-603-3757', 'quam.quis@Inscelerisquescelerisque.org', 'Kentucky', 'Grant Applicant'),
#  ('Sopoline Branch', 'Hispanic or Latinx', '1-910-619-1150', 'id.erat.Etiam@hendrerit.com', 'Montana', 'Loan Applicant'),
#  ('Sopoline Freeman', 'Asian', '1-655-403-5526', 'montes.nascetur.ridiculus@dolor.org', 'Oklahoma', 'Loan Applicant'),
#  ('Steel Sampson', 'Middle Eastern', '1-722-233-7884', 'congue.a.aliquet@malesuadafames.edu', 'Texas', 'Grant Applicant'),
#  ('Stephen Hardy', 'Black or African American', '1-261-646-9921', 'fames@Nullaaliquet.co.uk', 'Utah', 'Loan Applicant'),
#  ('Stephen Morales', 'American Indian or Alaska Native', '1-835-577-4377', 'rutrum.Fusce@faucibusutnulla.co.uk', 'Louisiana', 'Loan Applicant'),
#  ('Sybil Moss', 'Asian', '1-871-703-6337', 'ipsum.primis@rutrumjusto.co.uk', 'Vermont', 'Grant Applicant'),
#  ('Sybil Terrell', 'Middle Eastern', '1-917-630-2845', 'metus.Aenean@elit.ca', 'Virginia', 'Loan Applicant'),
#  ('Sydney Cortez', 'Middle Eastern', '1-469-248-1356', 'faucibus.Morbi@enimgravida.co.uk', 'Mississippi', 'Grant Applicant'),
#  ('Sylvester Head', 'American Indian or Alaska Native', '1-281-513-7729', 'natoque.penatibus.et@nascetur.org', 'Minnesota', 'Grant Applicant'),
#  ('Talon Owens', 'Native Hawaiian or Other Pacific Islander', '1-624-207-6303', 'euismod.est.arcu@turpisvitaepurus.ca', 'California', 'Grant Applicant'),
#  ('Tamekah Wilkerson', 'American Indian or Alaska Native', '1-618-817-2286', 'nisi.Cum.sociis@lectus.co.uk', 'Arizona', 'Grant Applicant'),
#  ('Tana Wyatt', 'Hispanic or Latinx', '1-782-878-4229', 'tincidunt.Donec.vitae@nonlorem.edu', 'Arizona', 'Loan Applicant'),
#  ('Tanek Moses', 'American Indian or Alaska Native', '1-564-898-1396', 'Cras.convallis.convallis@justoeu.edu', 'Arkansas', 'Loan Applicant'),
#  ('Tanisha Gill', 'Middle Eastern', '1-742-696-2505', 'netus@eliterat.net', 'Maryland', 'Loan Applicant'),
#  ('Tanisha Riggs', 'Middle Eastern', '1-580-279-8451', 'dolor@sed.net', 'Delaware', 'Grant Applicant'),
#  ('Tanner Foley', 'Black or African American', '1-416-993-8713', 'et@ultricesDuis.ca', 'Alabama', 'Loan Applicant'),
#  ('Tanya Oneill', 'Black or African American', '1-671-275-4227', 'nulla@Uttincidunt.co.uk', 'Wisconsin', 'Loan Applicant'),
#  ('Tara Goodwin', 'Native Hawaiian or Other Pacific Islander', '1-670-636-3890', 'nec.ligula@imperdietnecleo.com', 'Oregon', 'Grant Applicant'),
#  ('Tasha Gay', 'Black or African American', '1-611-378-0670', 'porttitor.tellus.non@mi.org', 'Nebraska', 'Loan Applicant'),
#  ('Tate Gamble', 'Middle Eastern', '1-229-115-3262', 'sapien.cursus.in@Nulla.edu', 'Wyoming', 'Grant Applicant'),
#  ('Tatyana Mills', 'Hispanic or Latinx', '1-563-318-3761', 'posuere.at.velit@Pellentesqueultriciesdignissim.org', 'Illinois', 'Loan Applicant'),
#  ('Tatyana Mitchell', 'Black or African American', '1-462-177-4421', 'quis.diam@CurabiturmassaVestibulum.ca', 'Alaska', 'Loan Applicant'),
#  ('Taylor Adkins', 'American Indian or Alaska Native', '1-716-214-5846', 'ligula.Nullam.enim@nullaInteger.co.uk', 'Pennsylvania', 'Loan Applicant'),
#  ('Teegan Pugh', 'Black or African American', '1-699-494-7704', 'ipsum@elementumpurusaccumsan.ca', 'Alabama', 'Loan Applicant'),
#  ('Teegan Villarreal', 'Native Hawaiian or Other Pacific Islander', '1-555-502-1935', 'ligula@telluseuaugue.org', 'Montana', 'Grant Applicant'),
#  ('Thane Hebert', 'Black or African American', '1-546-371-7245', 'sit.amet@parturientmontes.net', 'Maine', 'Grant Applicant'),
#  ('Theodore Simon', 'Asian', '1-467-749-4452', 'ut.cursus@sodalesMauris.co.uk', 'Missouri', 'Loan Applicant'),
#  ('Thor Garrett', 'Hispanic or Latinx', '1-773-217-8322', 'Vivamus@placeratorcilacus.org', 'Oregon', 'Loan Applicant'),
#  ('Timothy Horn', 'Asian', '1-934-231-4534', 'morbi.tristique@Maecenasmalesuada.com', 'Oregon', 'Loan Applicant'),
#  ('Tobias Levine', 'Middle Eastern', '1-316-445-0590', 'ut.aliquam.iaculis@velturpis.net', 'Wyoming', 'Loan Applicant'),
#  ('Travis Vaughan', 'American Indian or Alaska Native', '1-778-215-1979', 'malesuada.fringilla.est@Nuncquis.edu', 'Hawaii', 'Grant Applicant'),
#  ('Tyler Dyer', 'Hispanic or Latinx', '1-471-295-6457', 'mauris@eget.ca', 'Ohio', 'Loan Applicant'),
#  ('Ulla Harper', 'Middle Eastern', '1-840-903-1491', 'a.malesuada.id@dictumeu.edu', 'Georgia', 'Grant Applicant'),
#  ('Ulla Molina', 'Middle Eastern', '1-185-929-9452', 'ut.ipsum.ac@velit.com', 'Nebraska', 'Loan Applicant'),
#  ('Ulric Browning', 'Native Hawaiian or Other Pacific Islander', '1-884-560-3866', 'dis.parturient.montes@sollicitudincommodoipsum.edu', 'California', 'Grant Applicant'),
#  ('Ulric Mckinney', 'Native Hawaiian or Other Pacific Islander', '1-457-191-7556', 'Donec.at.arcu@Phasellus.net', 'Utah', 'Grant Applicant'),
#  ('Ulysses Stokes', 'American Indian or Alaska Native', '1-477-111-6440', 'at.arcu@metusIn.com', 'Arizona', 'Grant Applicant'),
#  ('Upton Rojas', 'Middle Eastern', '1-705-964-4518', 'ante.blandit.viverra@felis.ca', 'Indiana', 'Grant Applicant'),
#  ('Uriah Koch', 'Black or African American', '1-498-144-9720', 'a@ligulaAeneangravida.co.uk', 'Idaho', 'Grant Applicant'),
#  ('Uriel Wright', 'Hispanic or Latinx', '1-276-791-6529', 'nibh@leo.edu', 'Virginia', 'Grant Applicant'),
#  ('Urielle Underwood', 'Asian', '1-696-334-8735', 'Vestibulum@iaculis.co.uk', 'Wisconsin', 'Grant Applicant'),
#  ('Ursa Pittman', 'Middle Eastern', '1-845-776-1899', 'Curae@velvenenatis.net', 'California', 'Loan Applicant'),
#  ('Ursula Carroll', 'American Indian or Alaska Native', '1-369-763-5774', 'sem@risus.net', 'Montana', 'Grant Applicant'),
#  ('Ursula Casey', 'Hispanic or Latinx', '1-765-220-0647', 'elit.fermentum@nisimagna.edu', 'Pennsylvania', 'Grant Applicant'),
#  ('Valentine Wiggins', 'Middle Eastern', '1-124-835-3259', 'nonummy.ultricies@nibh.com', 'Colorado', 'Grant Applicant'),
#  ('Vera Johns', 'Native Hawaiian or Other Pacific Islander', '1-427-878-7730', 'cursus.luctus@enimEtiamgravida.com', 'Minnesota', 'Loan Applicant'),
#  ('Vera Lopez', 'Hispanic or Latinx', '1-707-875-6664', 'justo.sit.amet@pedeCum.co.uk', 'Virginia', 'Loan Applicant'),
#  ('Vernon Morrison', 'American Indian or Alaska Native', '1-938-635-5993', 'massa.rutrum@variuset.net', 'Idaho', 'Grant Applicant'),
#  ('Veronica Harding', 'Hispanic or Latinx', '1-335-275-5743', 'vehicula.risus@Namnulla.ca', 'Florida', 'Grant Applicant'),
#  ('Victor Cash', 'Middle Eastern', '1-838-931-0137', 'Duis@vitaedolorDonec.edu', 'Oregon', 'Loan Applicant'),
#  ('Victor Guerrero', 'Asian', '1-713-509-4007', 'faucibus@duisemper.ca', 'Wisconsin', 'Grant Applicant'),
#  ('Victoria Maynard', 'Black or African American', '1-589-181-9007', 'sit.amet.ornare@Praesent.org', 'Louisiana', 'Grant Applicant'),
#  ('Vielka Terrell', 'Native Hawaiian or Other Pacific Islander', '1-691-224-3628', 'sed.dictum.eleifend@condimentum.co.uk', 'Mississippi', 'Grant Applicant'),
#  ('Wade Kent', 'Hispanic or Latinx', '1-886-216-9235', 'posuere.at.velit@Nuncpulvinararcu.co.uk', 'Michigan', 'Loan Applicant'),
#  ('Walker Hayden', 'Hispanic or Latinx', '1-835-781-7473', 'nibh.enim@Proinultrices.ca', 'Iowa', 'Grant Applicant'),
#  ('Walker Leon', 'Hispanic or Latinx', '1-555-570-1486', 'Nam.ligula@Uttinciduntvehicula.com', 'Kansas', 'Loan Applicant'),
#  ('Wallace Holland', 'Hispanic or Latinx', '1-174-317-8752', 'malesuada@nunc.org', 'Minnesota', 'Grant Applicant'),
#  ('Wang Pickett', 'Black or African American', '1-804-477-3759', 'id.mollis@magnaLoremipsum.org', 'Illinois', 'Grant Applicant'),
#  ('Warren Moses', 'Hispanic or Latinx', '1-294-934-7673', 'amet.nulla.Donec@aptent.org', 'Maine', 'Grant Applicant'),
#  ('Wayne Bailey', 'Asian', '1-694-377-5182', 'Praesent@lacusNulla.com', 'Massachusetts', 'Grant Applicant'),
#  ('Wayne Blake', 'American Indian or Alaska Native', '1-721-747-6670', 'massa.non@Vivamus.org', 'Utah', 'Grant Applicant'),
#  ('William Dorsey', 'American Indian or Alaska Native', '1-354-745-6502', 'euismod.mauris.eu@Uttinciduntvehicula.ca', 'Oklahoma', 'Loan Applicant'),
#  ('Winifred Monroe', 'Native Hawaiian or Other Pacific Islander', '1-901-819-5551', 'consectetuer.adipiscing@quamdignissim.co.uk', 'Vermont', 'Loan Applicant'),
#  ('Winter Bradshaw', 'Hispanic or Latinx', '1-763-863-1094', 'ligula.Nullam.enim@sem.ca', 'Louisiana', 'Grant Applicant'),
#  ('Wyatt Combs', 'Hispanic or Latinx', '1-685-325-8443', 'interdum.Curabitur@dolorelitpellentesque.co.uk', 'Michigan', 'Grant Applicant'),
#  ('Wynne Albert', 'Middle Eastern', '1-940-451-7919', 'nec.malesuada.ut@eu.co.uk', 'Pennsylvania', 'Loan Applicant'),
#  ('Wynter Haley', 'American Indian or Alaska Native', '1-498-475-6729', 'euismod@sollicitudinorcisem.edu', 'Oklahoma', 'Grant Applicant'),
#  ('Wynter Matthews', 'Middle Eastern', '1-213-875-3044', 'euismod@nisi.edu', 'Iowa', 'Grant Applicant'),
#  ('Wyoming Oneil', 'Asian', '1-213-486-6368', 'iaculis.odio.Nam@atpretium.edu', 'Kansas', 'Loan Applicant'),
#  ('Wyoming Rosario', 'Black or African American', '1-266-743-4467', 'risus.Quisque@malesuada.net', 'Delaware', 'Grant Applicant'),
#  ('Xander Livingston', 'American Indian or Alaska Native', '1-957-244-2237', 'iaculis@risus.com', 'Connecticut', 'Grant Applicant'),
#  ('Xanthus Zimmerman', 'Native Hawaiian or Other Pacific Islander', '1-835-643-8081', 'neque.Nullam@ametconsectetueradipiscing.com', 'Alabama', 'Grant Applicant'),
#  ('Xavier Fry', 'Native Hawaiian or Other Pacific Islander', '1-257-671-0076', 'Quisque.fringilla.euismod@estconguea.net', 'Arkansas', 'Loan Applicant'),
#  ('Xavier Mann', 'American Indian or Alaska Native', '1-634-863-1987', 'commodo@egetipsumDonec.org', 'Nevada', 'Loan Applicant'),
#  ('Xaviera Bender', 'Native Hawaiian or Other Pacific Islander', '1-839-216-0688', 'eleifend@egestas.org', 'Colorado', 'Grant Applicant'),
#  ('Xena Nunez', 'Asian', '1-224-953-3976', 'facilisis.Suspendisse.commodo@Etiam.net', 'Colorado', 'Loan Applicant'),
#  ('Yardley Nolan', 'Hispanic or Latinx', '1-921-488-1189', 'vulputate.dui.nec@euismodmauris.net', 'Louisiana', 'Grant Applicant'),
#  ('Yasir Obrien', 'American Indian or Alaska Native', '1-552-348-2772', 'fermentum.fermentum.arcu@Maurisblanditenim.ca', 'Mississippi', 'Grant Applicant'),
#  ('Yetta Reilly', 'American Indian or Alaska Native', '1-476-234-7181', 'ut.odio.vel@maurissit.com', 'Ohio', 'Grant Applicant'),
#  ('Yoko Patrick', 'American Indian or Alaska Native', '1-699-216-9807', 'dolor.Donec@mattisCraseget.ca', 'Pennsylvania', 'Grant Applicant'),
#  ('Yoshi Conway', 'Asian', '1-166-192-5874', 'amet.luctus.vulputate@auguescelerisquemollis.net', 'Oregon', 'Grant Applicant'),
#  ('Yoshi Fitzpatrick', 'Middle Eastern', '1-973-393-5406', 'sapien@Proinvelnisl.org', 'Utah', 'Loan Applicant'),
#  ('Yoshio Holder', 'Hispanic or Latinx', '1-145-419-1957', 'molestie.orci@nascetur.com', 'Louisiana', 'Loan Applicant'),
#  ('Yuli Barber', 'Middle Eastern', '1-756-450-6620', 'erat.semper@pharetra.edu', 'Vermont', 'Grant Applicant'),
#  ('Yuli Fitzgerald', 'Middle Eastern', '1-229-453-9114', 'leo@euenimEtiam.org', 'California', 'Loan Applicant'),
#  ('Yuri Barrera', 'Native Hawaiian or Other Pacific Islander', '1-847-826-8141', 'non.massa@nullaInteger.ca', 'Hawaii', 'Loan Applicant'),
#  ('Yvonne Jimenez', 'Native Hawaiian or Other Pacific Islander', '1-806-618-5348', 'Proin@Nullaeget.co.uk', 'Michigan', 'Grant Applicant'),
#  ('Zachary Holman', 'American Indian or Alaska Native', '1-979-672-5255', 'pede@erosnectellus.com', 'Nevada', 'Loan Applicant'),
#  ('Zelenia Gomez', 'American Indian or Alaska Native', '1-679-610-2368', 'molestie.tortor@consectetueradipiscingelit.com', 'Wyoming', 'Loan Applicant'),
#  ('Zelenia Kelley', 'Hispanic or Latinx', '1-968-468-0374', 'aliquet@velmaurisInteger.ca', 'Florida', 'Loan Applicant'),
#  ('Zena Clay', 'Middle Eastern', '1-230-281-6254', 'ornare.lectus.ante@turpisIncondimentum.org', 'Minnesota', 'Grant Applicant'),
#  ('Zenaida Hahn', 'Hispanic or Latinx', '1-530-456-9598', 'nisi.magna.sed@Quisqueornaretortor.edu', 'Kansas', 'Grant Applicant'),
#  ('Zenaida Owen', 'Asian', '1-253-817-4194', 'magna@purusNullamscelerisque.ca', 'Georgia', 'Grant Applicant'),
#  ('Zephr Noble', 'Native Hawaiian or Other Pacific Islander', '1-796-922-0120', 'ac.mattis.ornare@tellusAeneanegestas.ca', 'Pennsylvania', 'Loan Applicant'),
#  ('Zeus Barton', 'Hispanic or Latinx', '1-711-146-3188', 'quis@mitempor.ca', 'Maryland', 'Loan Applicant'),
#  ('Zia Guy', 'American Indian or Alaska Native', '1-717-114-1807', 'mattis.Cras.eget@ipsumnuncid.net', 'Montana', 'Grant Applicant'),
#  ('Zia Sandoval', 'Native Hawaiian or Other Pacific Islander', '1-161-266-5001', 'enim.gravida@acrisusMorbi.co.uk', 'Kentucky', 'Grant Applicant'),
#  ('Zoe Strong', 'Black or African American', '1-963-774-6727', 'Nullam@metusvitaevelit.co.uk', 'Pennsylvania', 'Grant Applicant')]

# %% [markdown]
# # Exploratory Query - 5
# __Business Request:__ _The head of the initiative would like retain the current status of grant applicants. Return information regarding the number of total businesses that we currently have received an application for, the total amount overall being requested, the lowest amount requested by a business, the average amount requested amongst all applicants, and the highest amount requested by a business.__
#
# __Question:__ _What is the total number of businesses that have applied for a grant, what is sum amongst all requests, the lowest grant amount requested, the average grant amount requested, and the highest  grant amount requested._
#
# __Business Justification:__ _The team would like the current statistics of grant applicants for documentation purposes._
#
# SQL Features Used: _COUNT, SUM, MIN, MAX, ROUND, AVG_

# %%
# %%sql
# SELECT
#     COUNT(DISTINCT(grant_application_id)) AS Number_of_Businesses,
#     SUM(amount_requested) AS total_requested,
#     MIN(amount_requested) AS lowest_requested,
#     ROUND(AVG(amount_requested)) AS average_requested,
#     MAX(amount_requested) AS highest_requested
# FROM StateWideGrantApplication;
# Out:
#  * mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/Applicants
#    mysql://admin:***@lmu-isba-4715.cvjghynnkfgb.us-east-1.rds.amazonaws.com/LoanApplicants
# 1 rows affected.
# [(400, Decimal('31623656'), 1614, Decimal('79059'), 150000)]
